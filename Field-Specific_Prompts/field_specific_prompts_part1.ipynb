# %% [markdown]
# # Field-Specific Prompts - Part 1
#
# This notebook demonstrates prompts for various professional fields, including test cases for validation.
#
# ## Fields Covered
# 1. HR (Human Resources)
# 2. Teaching
# 3. Finance
# 4. Medicine
# 5. Legal
#
# ## Setup

# %%
# !pip install openai langchain langchain-community
from openai import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# Initialize the OpenAI client
client = OpenAI(api_key="Ke")

# Initialize ChatOpenAI for LangChain
chat_model = ChatOpenAI(
    temperature=0,
    openai_api_key=client.api_key,
    model_name="gpt-3.5-turbo"
)
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.4)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Collecting langchain-community
#   Downloading langchain_community-0.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.19)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.143)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain
#   Downloading langchain-0.3.9-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain)
#   Downloading langchain_core-0.3.21-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.3.8-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 19.4 MB/s eta 0:00:00
# Downloading langchain-0.3.9-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.5 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain_core-0.3.21-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 9.8 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.0 MB/s eta 0:00:00
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 981.8 kB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: SQLAlchemy, python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-core, langchain, langchain-community
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# Successfully installed SQLAlchemy-2.0.35 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.9 langchain-community-0.3.8 langchain-core-0.3.21 marshmallow-3.23.1 mypy-extensions-1.0.0 pydantic-settings-2.6.1 python-dotenv-1.0.1 typing-inspect-0.9.0
# <ipython-input-1-2ed1b917cc7c>:11: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   chat_model = ChatOpenAI(

# %% [markdown]
# ## Helper Functions

# %%
def get_completion(prompt, model="gpt-3.5-turbo", temperature=0):
    """Get completion from OpenAI API using the latest client"""
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature
    )
    return response.choices[0].message.content

def test_prompt(template, test_cases):
    """Test a prompt template with multiple cases"""
    print("Template:\n")
    print(template)
    print("\nTest Cases:\n")
    for case in test_cases:
        print(f"Input: {case}")
        prompt = template.format(text=case)
        result = get_completion(prompt)
        print(f"Output: {result}")
        print("-"*75)

# %% [markdown]
# [Previous sections (HR, Teaching, Finance, Medicine) remain unchanged...]
#
# ## 5. Legal
#
# ### Prompt 1: Legal Analysis

# %%
legal_analysis_template = """
Perform a legal analysis for the following case.

Include:
1. Case Overview
   - Key facts
   - Legal issues
   - Jurisdiction
   - Timeline

2. Legal Framework
   - Applicable laws
   - Relevant precedents
   - Regulatory requirements
   - Legal principles

3. Analysis
   - Legal arguments
   - Supporting evidence
   - Counter-arguments
   - Potential challenges

4. Recommendations
   - Legal strategy
   - Risk assessment
   - Next steps
   - Timeline

Case: {text}
"""

legal_analysis_test_cases = [
    "Intellectual property dispute over similar software patents",
    "Employment discrimination claim based on age and gender",
    "Contract breach in international business transaction"
]

print("Legal Analysis Generator:")
test_prompt(legal_analysis_template, legal_analysis_test_cases)
# Out:
# Legal Analysis Generator:
# Template:
#
#
# Perform a legal analysis for the following case.
#
# Include:
# 1. Case Overview
#    - Key facts
#    - Legal issues
#    - Jurisdiction
#    - Timeline
#
# 2. Legal Framework
#    - Applicable laws
#    - Relevant precedents
#    - Regulatory requirements
#    - Legal principles
#
# 3. Analysis
#    - Legal arguments
#    - Supporting evidence
#    - Counter-arguments
#    - Potential challenges
#
# 4. Recommendations
#    - Legal strategy
#    - Risk assessment
#    - Next steps
#    - Timeline
#
# Case: {text}
#
#
# Test Cases:
#
# Input: Intellectual property dispute over similar software patents
# Output: 1. Case Overview:
# Key facts: Company A has developed a software patent for a new technology that improves efficiency in data processing. Company B has recently released a similar software that Company A believes infringes on their patent.
# Legal issues: The main legal issue is whether Company B's software infringes on Company A's patent rights.
# Jurisdiction: The case falls under intellectual property law and will likely be heard in a federal court.
# Timeline: Company A filed a lawsuit against Company B for patent infringement six months ago, and the case is currently in the discovery phase.
#
# 2. Legal Framework:
# Applicable laws: The case will be governed by the Patent Act, which protects inventors' rights to their inventions.
# Relevant precedents: Previous court cases involving software patent disputes will be relevant in determining the outcome of this case.
# Regulatory requirements: Both companies must comply with the rules and procedures set forth by the court in the litigation process.
# Legal principles: The court will consider principles of patent law, including the novelty and non-obviousness of the invention, in determining whether infringement has occurred.
#
# 3. Analysis:
# Legal arguments: Company A can argue that Company B's software directly infringes on their patent by using the same technology without authorization. They can also argue that the similarities between the two software programs are too close to be coincidental.
# Supporting evidence: Company A can present technical experts to testify to the similarities between the two software programs and demonstrate how Company B's software infringes on their patent.
# Counter-arguments: Company B may argue that their software is sufficiently different from Company A's patent and does not infringe on their rights. They may also argue that the patent is invalid due to prior art.
# Potential challenges: One potential challenge could be proving the extent of damages caused by the infringement, as well as establishing a clear causal link between Company B's actions and those damages.
#
# 4. Recommendations:
# Legal strategy: Company A should continue to gather evidence to support their claim of patent infringement and work closely with their legal team to build a strong case.
# Risk assessment: The outcome of the case is uncertain, and there is a risk of losing the lawsuit or facing a lengthy legal battle. Company A should weigh the potential risks and benefits of continuing with the litigation.
# Next steps: Company A should continue with the discovery process and prepare for trial, while also exploring the possibility of settlement negotiations with Company B.
# Timeline: The case is likely to proceed to trial within the next year, depending on the court's schedule and any potential delays in the litigation process.
# ---------------------------------------------------------------------------
# Input: Employment discrimination claim based on age and gender
# Output: 1. Case Overview:
# Key facts: An employee has filed a lawsuit against their employer alleging discrimination based on age and gender. The employee claims that they were passed over for a promotion in favor of a younger, male colleague despite being more qualified for the position.
# Legal issues: The main legal issues in this case are whether the employer engaged in discriminatory practices based on age and gender in violation of anti-discrimination laws.
# Jurisdiction: The case falls under the jurisdiction of the relevant federal and state anti-discrimination laws.
# Timeline: The employee filed the lawsuit within the statute of limitations for discrimination claims, typically within 180 days to 300 days depending on the jurisdiction.
#
# 2. Legal Framework:
# Applicable laws: The Age Discrimination in Employment Act (ADEA) and Title VII of the Civil Rights Act of 1964 prohibit discrimination based on age and gender in the workplace.
# Relevant precedents: Courts have ruled in favor of employees in similar cases where there was evidence of discriminatory practices based on age and gender.
# Regulatory requirements: Employers are required to provide equal employment opportunities regardless of age or gender and are prohibited from engaging in discriminatory practices.
# Legal principles: The legal principles of disparate treatment and disparate impact may be relevant in analyzing the discrimination claim.
#
# 3. Analysis:
# Legal arguments: The employee can argue that they were qualified for the promotion and that the employer's decision was based on discriminatory factors such as age and gender.
# Supporting evidence: The employee can provide evidence of their qualifications, performance reviews, and any discriminatory comments or actions by the employer.
# Counter-arguments: The employer may argue that the promotion decision was based on legitimate business reasons unrelated to age or gender.
# Potential challenges: Proving discriminatory intent can be challenging, as employers may have legitimate reasons for their decisions that are not discriminatory.
#
# 4. Recommendations:
# Legal strategy: The employee should gather evidence to support their discrimination claim, such as performance evaluations, witness statements, and any discriminatory comments or actions by the employer.
# Risk assessment: The employee should assess the potential risks and benefits of pursuing the lawsuit, considering the costs, time, and potential outcomes of litigation.
# Next steps: The employee should consider filing a complaint with the Equal Employment Opportunity Commission (EEOC) before pursuing a lawsuit, as this is often a required step in discrimination cases.
# Timeline: The employee should consult with an attorney to determine the appropriate timeline for filing a lawsuit and pursuing legal action.
# ---------------------------------------------------------------------------
# Input: Contract breach in international business transaction
# Output: 1. Case Overview:
# Key facts: Company A, a US-based company, entered into a contract with Company B, a UK-based company, for the purchase of goods. Company B failed to deliver the goods as per the contract terms, resulting in a breach of contract.
# Legal issues: Breach of contract, international business transaction
# Jurisdiction: The contract was between a US-based company and a UK-based company, potentially involving international laws and regulations.
# Timeline: The contract was entered into on [date], with delivery of goods scheduled for [date]. The breach occurred on [date].
#
# 2. Legal Framework:
# Applicable laws: The United Nations Convention on Contracts for the International Sale of Goods (CISG) may apply to this case, as it governs international sales contracts between parties from different countries.
# Relevant precedents: Previous cases involving breach of contract in international business transactions may provide guidance on how similar situations have been resolved.
# Regulatory requirements: Any relevant trade regulations or international trade agreements between the US and UK may impact the resolution of this case.
# Legal principles: The principle of pacta sunt servanda (agreements must be kept) is a fundamental principle of contract law that may apply in this case.
#
# 3. Analysis:
# Legal arguments: Company A can argue that Company B's failure to deliver the goods as per the contract terms constitutes a breach of contract. They can also argue for damages to compensate for any losses incurred due to the breach.
# Supporting evidence: The contract itself, communication between the parties regarding the breach, and any documentation related to the transaction can serve as evidence to support Company A's claims.
# Counter-arguments: Company B may argue that the breach was due to unforeseen circumstances or force majeure events that were beyond their control.
# Potential challenges: Resolving a breach of contract in an international context can be complex due to differences in laws and regulations between countries, as well as potential jurisdictional issues.
#
# 4. Recommendations:
# Legal strategy: Company A should consider seeking legal advice from attorneys experienced in international business transactions and contract law. They may also consider mediation or arbitration as alternative dispute resolution methods.
# Risk assessment: Company A should assess the potential risks and costs associated with pursuing legal action against Company B, including the likelihood of success and potential damages awarded.
# Next steps: Company A should formally notify Company B of the breach and attempt to negotiate a resolution. If a resolution cannot be reached, they may need to consider legal action.
# Timeline: Company A should act promptly to address the breach and pursue legal action if necessary, as delays could impact their ability to recover damages.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Prompt 2: Contract Review

# %%
legal_contract_template = """
Perform a contract review for the following agreement.

Include:
1. Document Review
   - Key terms
   - Obligations
   - Rights
   - Limitations

2. Risk Assessment
   - Legal risks
   - Business risks
   - Compliance issues
   - Potential conflicts

3. Recommendations
   - Required changes
   - Additional clauses
   - Clarifications needed
   - Protective measures

4. Implementation
   - Next steps
   - Timeline
   - Required approvals
   - Documentation needs

Agreement: {text}
"""

legal_contract_test_cases = [
    "Software development agreement with offshore contractor",
    "Commercial lease for retail space in shopping center",
    "Partnership agreement for new business venture"
]

print("Contract Review Generator:")
test_prompt(legal_contract_template, legal_contract_test_cases)
# Out:
# Contract Review Generator:
# Template:
#
#
# Perform a contract review for the following agreement.
#
# Include:
# 1. Document Review
#    - Key terms
#    - Obligations
#    - Rights
#    - Limitations
#
# 2. Risk Assessment
#    - Legal risks
#    - Business risks
#    - Compliance issues
#    - Potential conflicts
#
# 3. Recommendations
#    - Required changes
#    - Additional clauses
#    - Clarifications needed
#    - Protective measures
#
# 4. Implementation
#    - Next steps
#    - Timeline
#    - Required approvals
#    - Documentation needs
#
# Agreement: {text}
#
#
# Test Cases:
#
# Input: Software development agreement with offshore contractor
# Output: 1. Document Review:
# - Key terms: The agreement outlines the scope of work, payment terms, intellectual property rights, confidentiality provisions, and termination clauses.
# - Obligations: The offshore contractor is responsible for developing the software according to the specifications provided by the client.
# - Rights: The client has the right to review and approve the deliverables, as well as the right to terminate the agreement if the contractor fails to meet the agreed-upon deadlines.
# - Limitations: The agreement does not specify liability limitations or indemnification clauses in case of breach of contract.
#
# 2. Risk Assessment:
# - Legal risks: There may be legal risks associated with intellectual property rights, data protection laws, and jurisdictional issues when working with an offshore contractor.
# - Business risks: Delays in software development, quality issues, and communication challenges could pose business risks.
# - Compliance issues: Compliance with data protection regulations, export control laws, and tax implications of working with an offshore contractor need to be considered.
# - Potential conflicts: Conflicts may arise if there are disagreements over the scope of work, payment terms, or intellectual property rights.
#
# 3. Recommendations:
# - Required changes: Include liability limitations and indemnification clauses to protect both parties in case of breach of contract.
# - Additional clauses: Add provisions for dispute resolution mechanisms and governing law to address potential conflicts.
# - Clarifications needed: Clarify the process for handling changes to the scope of work and the responsibilities of each party in case of delays.
# - Protective measures: Implement data protection measures and ensure compliance with relevant laws and regulations.
#
# 4. Implementation:
# - Next steps: Schedule a meeting with the offshore contractor to discuss the recommended changes and clarifications.
# - Timeline: Set a timeline for implementing the required changes and obtaining necessary approvals.
# - Required approvals: Obtain approval from both parties for the revised agreement.
# - Documentation needs: Update the agreement with the recommended changes and ensure all parties have a signed copy for reference.
# ---------------------------------------------------------------------------
# Input: Commercial lease for retail space in shopping center
# Output: 1. Document Review:
# - Key terms: The agreement outlines the terms of the lease for a retail space in a shopping center, including the rental amount, lease term, maintenance responsibilities, and any additional fees.
# - Obligations: The tenant is obligated to pay rent on time, maintain the premises, and comply with all laws and regulations. The landlord is obligated to provide a safe and habitable space.
# - Rights: The tenant has the right to use the premises for commercial purposes and to exclusive possession during the lease term. The landlord has the right to receive rent and access the premises for maintenance.
# - Limitations: The agreement may have limitations on subleasing, alterations to the premises, and use of the space for specific purposes.
#
# 2. Risk Assessment:
# - Legal risks: Potential legal risks include disputes over maintenance responsibilities, rent increases, and lease termination. It is important to ensure that the agreement complies with all relevant laws and regulations.
# - Business risks: Business risks may include changes in the shopping center's foot traffic, competition from other tenants, and economic downturns affecting the retail industry.
# - Compliance issues: Compliance issues may arise if the tenant fails to adhere to zoning laws, building codes, or other regulations. It is important to ensure that the lease agreement addresses these concerns.
# - Potential conflicts: Potential conflicts may arise over rent increases, maintenance disputes, or lease renewal negotiations. It is important to have mechanisms in place to address and resolve conflicts.
#
# 3. Recommendations:
# - Required changes: Consider including provisions for rent escalation clauses, maintenance responsibilities, and dispute resolution mechanisms.
# - Additional clauses: Consider adding clauses addressing signage rights, parking allocations, and lease renewal options.
# - Clarifications needed: Clarify any ambiguous language regarding maintenance responsibilities, common area expenses, and lease termination procedures.
# - Protective measures: Include provisions for security deposits, insurance requirements, and indemnification clauses to protect both parties.
#
# 4. Implementation:
# - Next steps: Review and negotiate any proposed changes with the other party. Obtain legal advice if necessary.
# - Timeline: Set a timeline for finalizing the agreement, signing the lease, and taking possession of the retail space.
# - Required approvals: Ensure that all necessary approvals from landlords, tenants, and any relevant authorities are obtained.
# - Documentation needs: Keep thorough records of all communications, negotiations, and signed agreements for future reference.
# ---------------------------------------------------------------------------
# Input: Partnership agreement for new business venture
# Output: 1. Document Review:
# - Key terms: The agreement outlines the terms of the partnership between the parties involved in the new business venture, including profit sharing, decision-making authority, and responsibilities.
# - Obligations: Each party's obligations are clearly defined, including financial contributions, roles and responsibilities, and commitment to the success of the venture.
# - Rights: The agreement outlines the rights of each partner, such as the right to participate in decision-making, access to financial information, and the right to share in profits.
# - Limitations: The agreement may include limitations on the partners' ability to make unilateral decisions, restrictions on transferring ownership interests, and limitations on liability.
#
# 2. Risk Assessment:
# - Legal risks: Potential legal risks include disputes over profit sharing, breach of contract, and liability issues. It is important to ensure that the agreement is legally sound and enforceable.
# - Business risks: Business risks may include market fluctuations, competition, and operational challenges. The agreement should address how these risks will be managed and mitigated.
# - Compliance issues: Compliance with laws and regulations, such as tax laws and business licensing requirements, should be considered to avoid potential legal issues.
# - Potential conflicts: Conflicts may arise between partners regarding decision-making, financial matters, or the direction of the business. The agreement should include mechanisms for resolving conflicts in a fair and efficient manner.
#
# 3. Recommendations:
# - Required changes: It may be necessary to clarify certain terms, add provisions for dispute resolution, or include additional protections for the partners.
# - Additional clauses: Consider adding clauses related to confidentiality, non-compete agreements, and exit strategies in case the partnership needs to be dissolved.
# - Clarifications needed: Ensure that all terms are clearly defined and understood by all parties involved to avoid misunderstandings or disputes in the future.
# - Protective measures: Include provisions to protect the partners' interests, such as indemnification clauses, insurance requirements, and limitations on liability.
#
# 4. Implementation:
# - Next steps: The next steps may include revising the agreement based on the recommendations, obtaining legal review and approval, and signing the finalized agreement.
# - Timeline: Establish a timeline for implementing the partnership agreement, including deadlines for fulfilling obligations and milestones for monitoring the success of the venture.
# - Required approvals: Ensure that all parties involved in the partnership agreement have the necessary approvals from their respective stakeholders before moving forward.
# - Documentation needs: Keep thorough documentation of the partnership agreement, including signed copies, financial records, and any amendments or updates to the agreement.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Prompt 3: Compliance Review

# %%
legal_compliance_template = """
Perform a compliance review for the following scenario.

Include:
1. Regulatory Framework
   - Applicable regulations
   - Industry standards
   - Reporting requirements
   - Compliance deadlines

2. Current Status
   - Compliance level
   - Documentation
   - Processes
   - Training needs

3. Gap Analysis
   - Identified gaps
   - Risk levels
   - Priority areas
   - Required actions

4. Action Plan
   - Remediation steps
   - Resource needs
   - Timeline
   - Monitoring plan

Scenario: {text}
"""

legal_compliance_test_cases = [
    "Healthcare provider implementing new patient data privacy measures",
    "Fintech startup launching new payment processing service",
    "Manufacturing company expanding operations internationally"
]

print("Compliance Review Generator:")
test_prompt(legal_compliance_template, legal_compliance_test_cases)
# Out:
# Compliance Review Generator:
# Template:
#
#
# Perform a compliance review for the following scenario.
#
# Include:
# 1. Regulatory Framework
#    - Applicable regulations
#    - Industry standards
#    - Reporting requirements
#    - Compliance deadlines
#
# 2. Current Status
#    - Compliance level
#    - Documentation
#    - Processes
#    - Training needs
#
# 3. Gap Analysis
#    - Identified gaps
#    - Risk levels
#    - Priority areas
#    - Required actions
#
# 4. Action Plan
#    - Remediation steps
#    - Resource needs
#    - Timeline
#    - Monitoring plan
#
# Scenario: {text}
#
#
# Test Cases:
#
# Input: Healthcare provider implementing new patient data privacy measures
# Output: 1. Regulatory Framework:
# - Applicable regulations: HIPAA (Health Insurance Portability and Accountability Act), HITECH (Health Information Technology for Economic and Clinical Health Act), GDPR (General Data Protection Regulation)
# - Industry standards: Healthcare industry standards for patient data privacy
# - Reporting requirements: Reporting of data breaches to patients and regulatory authorities
# - Compliance deadlines: Ongoing compliance with regulations and standards
#
# 2. Current Status:
# - Compliance level: Partial compliance with existing patient data privacy regulations
# - Documentation: Some documentation in place regarding patient data privacy measures
# - Processes: Some processes in place for handling patient data, but gaps exist
# - Training needs: Staff may require additional training on new patient data privacy measures
#
# 3. Gap Analysis:
# - Identified gaps: Lack of comprehensive patient data privacy policy, incomplete staff training, inadequate data breach response plan
# - Risk levels: High risk of data breaches and non-compliance with regulations
# - Priority areas: Developing a comprehensive patient data privacy policy, providing staff training, implementing a data breach response plan
# - Required actions: Develop policy, provide training, implement data breach response plan
#
# 4. Action Plan:
# - Remediation steps: Develop and implement a comprehensive patient data privacy policy, provide staff training on new measures, create and implement a data breach response plan
# - Resource needs: Dedicated staff for policy development, training resources, IT resources for data breach response plan
# - Timeline: Policy development within 1 month, staff training within 2 months, data breach response plan implementation within 3 months
# - Monitoring plan: Regular audits and reviews of patient data privacy measures, ongoing staff training, regular testing of data breach response plan.
# ---------------------------------------------------------------------------
# Input: Fintech startup launching new payment processing service
# Output: 1. Regulatory Framework:
# - Applicable regulations: Payment Services Directive 2 (PSD2), General Data Protection Regulation (GDPR), Anti-Money Laundering (AML) regulations
# - Industry standards: Payment Card Industry Data Security Standard (PCI DSS)
# - Reporting requirements: Regular reporting to regulatory authorities on transaction volumes, customer data security measures, and AML compliance
# - Compliance deadlines: Ongoing compliance with PSD2 and GDPR, annual PCI DSS certification, regular AML audits
#
# 2. Current Status:
# - Compliance level: Partial compliance with PSD2 and GDPR, no PCI DSS certification, AML policies in place but not regularly audited
# - Documentation: Some documentation in place for PSD2 and GDPR compliance, limited documentation for PCI DSS and AML
# - Processes: Some processes in place for customer data security and AML checks, but not consistently followed
# - Training needs: Staff training on PSD2, GDPR, PCI DSS, and AML requirements needed
#
# 3. Gap Analysis:
# - Identified gaps: Lack of PCI DSS certification, inconsistent AML audits, incomplete documentation for compliance, staff training needs
# - Risk levels: High risk for data breaches, potential regulatory fines for non-compliance, reputational damage
# - Priority areas: PCI DSS certification, AML audits, staff training, documentation completeness
# - Required actions: Obtain PCI DSS certification, conduct regular AML audits, provide staff training, update documentation
#
# 4. Action Plan:
# - Remediation steps: Engage a PCI DSS compliance consultant, schedule AML audits, develop staff training program, update compliance documentation
# - Resource needs: PCI DSS consultant, AML audit firm, training materials, compliance officer
# - Timeline: Obtain PCI DSS certification within 6 months, conduct AML audits annually, complete staff training within 3 months, update documentation within 3 months
# - Monitoring plan: Regularly review compliance documentation, conduct internal audits, track staff training completion, monitor AML audit results.
# ---------------------------------------------------------------------------
# Input: Manufacturing company expanding operations internationally
# Output: 1. Regulatory Framework:
#    - Applicable regulations: International trade regulations, export control laws, labor laws, environmental regulations, tax laws, etc.
#    - Industry standards: ISO standards, industry-specific regulations, etc.
#    - Reporting requirements: Customs declarations, tax filings, environmental impact reports, etc.
#    - Compliance deadlines: Vary depending on the specific regulation or requirement.
#
# 2. Current Status:
#    - Compliance level: Partial compliance in some areas, lack of awareness in others.
#    - Documentation: Some documentation in place, but gaps exist.
#    - Processes: Some processes established, but not consistently followed.
#    - Training needs: Employees need training on international trade regulations, export controls, and other relevant areas.
#
# 3. Gap Analysis:
#    - Identified gaps: Lack of understanding of international trade regulations, incomplete documentation, inconsistent processes.
#    - Risk levels: High risk of non-compliance with international regulations, potential legal and financial consequences.
#    - Priority areas: Training on international trade regulations, establishing robust documentation processes, ensuring consistent compliance with export controls.
#    - Required actions: Develop training programs, update documentation, streamline processes, conduct regular compliance audits.
#
# 4. Action Plan:
#    - Remediation steps: Develop and implement training programs, update documentation, establish clear processes, conduct compliance audits.
#    - Resource needs: Training resources, compliance experts, additional staff if necessary.
#    - Timeline: Training to be completed within 3 months, documentation updates within 6 months, compliance audits to be conducted annually.
#    - Monitoring plan: Regularly review compliance status, conduct internal audits, address any issues promptly.
# ---------------------------------------------------------------------------
