# %% [markdown]
# # Field-Specific Prompts - Part 2
#
# This notebook demonstrates prompts for various professional fields, including test cases for validation.
#
# ## Fields Covered
# 1. Marketing
# 2. Technology
# 3. Customer Support
# 4. Creative Writing
# 5. Research
#
# ## Setup

# %%
# !pip install openai langchain langchain-community
from openai import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# Initialize the OpenAI client
client = OpenAI(api_key="sk-proj-V5cLGxn4euz06XApxKMD8PymW-fake")
# Initialize ChatOpenAI for LangChain
chat_model = ChatOpenAI(
    temperature=0,
    openai_api_key=client.api_key,
    model_name="gpt-3.5-turbo"
)
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.4)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Collecting langchain-community
#   Downloading langchain_community-0.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.19)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.143)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain
#   Downloading langchain-0.3.9-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain)
#   Downloading langchain_core-0.3.21-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.3.8-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.7 MB/s eta 0:00:00
# Downloading langchain-0.3.9-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain_core-0.3.21-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 5.6 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 26.2 MB/s eta 0:00:00
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: SQLAlchemy, python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-core, langchain, langchain-community
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# Successfully installed SQLAlchemy-2.0.35 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.9 langchain-community-0.3.8 langchain-core-0.3.21 marshmallow-3.23.1 mypy-extensions-1.0.0 pydantic-settings-2.6.1 python-dotenv-1.0.1 typing-inspect-0.9.0
# <ipython-input-1-11d6829332af>:10: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   chat_model = ChatOpenAI(

# %% [markdown]
# ## Helper Functions

# %%
def get_completion(prompt, model="gpt-3.5-turbo", temperature=0):
    """Get completion from OpenAI API using the latest client"""
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature
    )
    return response.choices[0].message.content

def test_prompt(template, test_cases):
    """Test a prompt template with multiple cases"""
    print("Template:\n")
    print(template)
    print("\nTest Cases:\n")
    for case in test_cases:
        print(f"Input: {case}")
        prompt = template.format(text=case)
        result = get_completion(prompt)
        print(f"Output: {result}")
        print("-"*75)

# %% [markdown]
# ## 1. Marketing
#
# ### Campaign Strategy

# %%
marketing_template = """
Create a marketing campaign strategy for: {text}

Include:
1. Campaign Overview
   - Objectives
   - Target audience
   - Value proposition
   - Success metrics

2. Marketing Mix
   - Product positioning
   - Pricing strategy
   - Distribution channels
   - Promotional tactics

3. Content Strategy
   - Key messages
   - Content types
   - Channel mix
   - Content calendar
"""

marketing_test_cases = [
    "AI-powered fitness app",
    "Sustainable fashion brand",
    "Online learning platform"
]

test_prompt(marketing_template, marketing_test_cases)
# Out:
# Template:
#
#
# Create a marketing campaign strategy for: {text}
#
# Include:
# 1. Campaign Overview
#    - Objectives
#    - Target audience
#    - Value proposition
#    - Success metrics
#
# 2. Marketing Mix
#    - Product positioning
#    - Pricing strategy
#    - Distribution channels
#    - Promotional tactics
#
# 3. Content Strategy
#    - Key messages
#    - Content types
#    - Channel mix
#    - Content calendar
#
#
# Test Cases:
#
# Input: AI-powered fitness app
# Output:
#
# 1. Campaign Overview:
#    - Objectives: Increase app downloads, engage users, and drive subscriptions.
#    - Target audience: Fitness enthusiasts, tech-savvy individuals, and those looking for personalized workout plans.
#    - Value proposition: Personalized AI-powered workout plans, real-time feedback, progress tracking, and goal setting.
#    - Success metrics: Number of app downloads, user engagement metrics (such as time spent on the app and frequency of use), and subscription conversion rate.
#
# 2. Marketing Mix:
#    - Product positioning: Position the app as a cutting-edge fitness solution that offers personalized and effective workout plans.
#    - Pricing strategy: Offer a freemium model with basic features available for free and premium features accessible through a subscription.
#    - Distribution channels: App stores, social media platforms, fitness blogs, and partnerships with gyms and fitness influencers.
#    - Promotional tactics: Offer a limited-time free trial of premium features, run social media ads targeting fitness enthusiasts, collaborate with fitness influencers for sponsored content, and host virtual fitness challenges.
#
# 3. Content Strategy:
#    - Key messages: Emphasize the convenience and effectiveness of personalized AI-powered workout plans, the benefits of real-time feedback, and the ability to track progress and set goals.
#    - Content types: Workout videos, success stories from app users, tips from fitness experts, and behind-the-scenes looks at the app's AI technology.
#    - Channel mix: Social media platforms (Instagram, Facebook, TikTok), email newsletters, blog posts, and in-app notifications.
#    - Content calendar: Plan to release new workout plans and content regularly, promote special events or challenges, and share user testimonials to keep engagement high.
# ---------------------------------------------------------------------------
# Input: Sustainable fashion brand
# Output:
#
# 1. Campaign Overview:
# - Objectives: Increase brand awareness, drive website traffic, and increase sales of sustainable fashion products.
# - Target audience: Eco-conscious consumers who prioritize sustainability in their purchasing decisions.
# - Value proposition: Offering stylish and high-quality fashion items that are ethically produced and environmentally friendly.
# - Success metrics: Increase in website traffic, growth in social media engagement, and increase in sales of sustainable fashion products.
#
# 2. Marketing Mix:
# - Product positioning: Position the brand as a leader in sustainable fashion, highlighting the use of eco-friendly materials and ethical production practices.
# - Pricing strategy: Offer competitive pricing to attract customers who may be hesitant to pay a premium for sustainable fashion.
# - Distribution channels: Sell products online through the brand's website and partner with select retailers who align with the brand's values.
# - Promotional tactics: Collaborate with influencers and eco-conscious bloggers to promote the brand, run social media campaigns highlighting the brand's sustainability efforts, and offer discounts and promotions to drive sales.
#
# 3. Content Strategy:
# - Key messages: Emphasize the brand's commitment to sustainability, the use of eco-friendly materials, and the ethical production practices.
# - Content types: Create blog posts, social media posts, videos, and email newsletters showcasing the brand's sustainable fashion products and sharing tips on how consumers can make more sustainable fashion choices.
# - Channel mix: Utilize Instagram, Facebook, Pinterest, and TikTok to reach a younger audience interested in sustainable fashion, as well as email marketing to engage with existing customers.
# - Content calendar: Plan out a content calendar that includes regular posts highlighting different sustainable fashion products, behind-the-scenes looks at the brand's production process, and tips for incorporating sustainable fashion into everyday style.
# ---------------------------------------------------------------------------
# Input: Online learning platform
# Output:
#
# 1. Campaign Overview:
#    - Objectives: Increase brand awareness, drive user acquisition, and increase engagement on the platform.
#    - Target audience: Students, professionals, and lifelong learners looking to enhance their skills or learn something new.
#    - Value proposition: Access to high-quality courses from industry experts, flexible learning options, and affordable pricing.
#    - Success metrics: Increase in website traffic, growth in user registrations, increase in course enrollments, and positive feedback from users.
#
# 2. Marketing Mix:
#    - Product positioning: Position the online learning platform as a convenient and effective way to learn new skills and advance in one's career.
#    - Pricing strategy: Offer a mix of free and paid courses, with competitive pricing for premium courses and subscription options for unlimited access.
#    - Distribution channels: Utilize social media platforms, email marketing, partnerships with educational institutions, and online advertising to reach the target audience.
#    - Promotional tactics: Offer discounts on course bundles, run referral programs, host webinars and virtual events, and collaborate with influencers in the education space.
#
# 3. Content Strategy:
#    - Key messages: Emphasize the benefits of online learning, such as flexibility, accessibility, and the opportunity to learn from experts in various fields.
#    - Content types: Create blog posts, videos, infographics, and case studies highlighting success stories of learners who have benefited from the platform.
#    - Channel mix: Utilize the online learning platform's blog, social media channels, email newsletters, and paid advertising to distribute content.
#    - Content calendar: Plan a mix of evergreen content, seasonal promotions, and timely updates to keep users engaged and informed about new course offerings.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 2. Technology
#
# ### Technical Documentation

# %%
tech_template = """
Create technical documentation for: {text}

Include:
1. System Overview
   - Purpose
   - Architecture
   - Components
   - Dependencies

2. Implementation
   - Setup steps
   - Configuration
   - API endpoints
   - Data models

3. Usage Guide
   - Examples
   - Best practices
   - Common issues
   - Troubleshooting
"""

tech_test_cases = [
    "OAuth2 authentication system",
    "Real-time data sync service",
    "Mobile push notifications"
]

test_prompt(tech_template, tech_test_cases)
# Out:
# Template:
#
#
# Create technical documentation for: {text}
#
# Include:
# 1. System Overview
#    - Purpose
#    - Architecture
#    - Components
#    - Dependencies
#
# 2. Implementation
#    - Setup steps
#    - Configuration
#    - API endpoints
#    - Data models
#
# 3. Usage Guide
#    - Examples
#    - Best practices
#    - Common issues
#    - Troubleshooting
#
#
# Test Cases:
#
# Input: OAuth2 authentication system
# Output: # OAuth2 Authentication System Technical Documentation
#
# ## 1. System Overview
#
# ### Purpose
# The OAuth2 authentication system is designed to provide secure access to resources by allowing users to grant permissions to third-party applications without sharing their credentials. It is commonly used in web and mobile applications to authenticate users and authorize access to protected resources.
#
# ### Architecture
# The OAuth2 authentication system follows a client-server architecture where the client (third-party application) requests access to resources on behalf of the user from the authorization server. The authorization server authenticates the user and issues access tokens to the client, which can then be used to access protected resources from the resource server.
#
# ### Components
# - Client: The third-party application requesting access to resources.
# - Authorization Server: Responsible for authenticating the user and issuing access tokens.
# - Resource Server: Hosts the protected resources that the client wants to access.
# - User: The entity that owns the resources and grants permissions to the client.
#
# ### Dependencies
# The OAuth2 authentication system relies on secure communication protocols such as HTTPS to protect the transmission of access tokens and user credentials. It also requires the client and resource server to support the OAuth2 protocol for authentication and authorization.
#
# ## 2. Implementation
#
# ### Setup Steps
# 1. Register the client application with the authorization server.
# 2. Obtain client credentials (client ID and client secret) from the authorization server.
# 3. Implement OAuth2 authentication flow in the client application.
# 4. Configure the client application to redirect users to the authorization server for authentication.
#
# ### Configuration
# - Client ID: Unique identifier for the client application.
# - Client Secret: Secret key used to authenticate the client with the authorization server.
# - Authorization Endpoint: URL where users authenticate and authorize access to resources.
# - Token Endpoint: URL where clients exchange authorization codes for access tokens.
#
# ### API Endpoints
# - Authorization Endpoint: `/oauth2/authorize`
# - Token Endpoint: `/oauth2/token`
# - Resource Endpoint: `/api/resource`
#
# ### Data Models
# - User: Represents a user in the system with unique identifier and permissions.
# - Client: Represents a third-party application with client ID and client secret.
#
# ## 3. Usage Guide
#
# ### Examples
# 1. User logs in to the client application and is redirected to the authorization server for authentication.
# 2. User grants permissions to the client application to access resources on their behalf.
# 3. Client application exchanges authorization code for access token to access protected resources.
#
# ### Best Practices
# - Use HTTPS to secure communication between client, authorization server, and resource server.
# - Implement token expiration and refresh mechanisms to ensure security.
# - Store client credentials securely and avoid hardcoding them in the client application.
#
# ### Common Issues
# - Invalid client credentials: Check that the client ID and client secret are correct.
# - Expired access token: Refresh the access token using the refresh token if available.
# - User denies access: Handle authorization errors gracefully and provide clear error messages to users.
#
# ### Troubleshooting
# - Check server logs for error messages and stack traces.
# - Use OAuth2 debugging tools to inspect HTTP requests and responses.
# - Reach out to the authorization server support team for assistance with specific issues.
#
# By following the guidelines outlined in this technical documentation, developers can successfully implement and integrate the OAuth2 authentication system into their applications to provide secure and seamless access to resources for users.
# ---------------------------------------------------------------------------
# Input: Real-time data sync service
# Output:
#
# 1. System Overview
#
# Purpose:
# The real-time data sync service is designed to synchronize data between multiple systems in real-time, ensuring that all systems have the most up-to-date information at all times.
#
# Architecture:
# The service follows a client-server architecture, where clients send data updates to the server, which then distributes these updates to all connected clients. The server uses a pub/sub messaging system to efficiently broadcast updates to all clients.
#
# Components:
# - Client: The application or system that sends data updates to the server.
# - Server: The central component that receives data updates from clients and distributes them to all connected clients.
# - Pub/Sub Messaging System: Used to broadcast data updates to all clients in real-time.
#
# Dependencies:
# - Pub/Sub messaging system (e.g. Redis, RabbitMQ)
# - Database for storing and retrieving data updates
#
# 2. Implementation
#
# Setup steps:
# 1. Install and configure the pub/sub messaging system.
# 2. Set up the server application on a dedicated server or cloud platform.
# 3. Configure the server to connect to the pub/sub messaging system.
# 4. Install and configure the client application on each system that needs to sync data.
#
# Configuration:
# - Server configuration: Specify the pub/sub messaging system connection details and any other relevant settings.
# - Client configuration: Specify the server endpoint and any authentication details required to connect to the server.
#
# API endpoints:
# - POST /update: Used by clients to send data updates to the server.
# - GET /updates: Used by clients to retrieve the latest data updates from the server.
#
# Data models:
# - Data update: Contains information about the updated data, such as the data type, ID, and new values.
#
# 3. Usage Guide
#
# Examples:
# - Client A sends an update to the server with the new customer information.
# - Server broadcasts the update to all connected clients, including Client B and Client C.
# - Client B and Client C receive the update and update their local databases with the new customer information.
#
# Best practices:
# - Use a consistent data model across all systems to ensure seamless synchronization.
# - Implement error handling and retry mechanisms to handle network issues or server downtime.
# - Monitor system performance and scalability to ensure smooth operation as the number of clients grows.
#
# Common issues:
# - Network connectivity issues causing delays in data synchronization.
# - Data conflicts when multiple clients update the same data simultaneously.
# - Server overload due to a high volume of data updates.
#
# Troubleshooting:
# - Check network connectivity between clients and the server.
# - Monitor server logs for any error messages or performance issues.
# - Verify data consistency across all connected systems to identify any synchronization issues.
# ---------------------------------------------------------------------------
# Input: Mobile push notifications
# Output:
#
# 1. System Overview:
#
# Purpose:
# Mobile push notifications are a way to send messages or alerts to users' mobile devices even when they are not actively using the app. This helps in engaging users, providing important updates, and increasing user retention.
#
# Architecture:
# The architecture of mobile push notifications typically involves a backend server that sends messages to a push notification service (such as Firebase Cloud Messaging for Android or Apple Push Notification Service for iOS), which then delivers the notifications to the respective devices.
#
# Components:
# - Backend server: Responsible for sending push notifications to the push notification service.
# - Push notification service: Handles the delivery of notifications to mobile devices.
# - Mobile devices: Receive and display the push notifications.
#
# Dependencies:
# - Push notification service SDK: Required to integrate push notifications into the mobile app.
# - Internet connection: Necessary for the mobile device to receive push notifications.
#
# 2. Implementation:
#
# Setup steps:
# 1. Register for a developer account with the push notification service provider.
# 2. Integrate the push notification service SDK into the mobile app.
# 3. Obtain necessary credentials (API keys, tokens) from the push notification service.
# 4. Implement the code to handle receiving and displaying push notifications in the mobile app.
#
# Configuration:
# Configuration settings may include setting up notification channels, defining notification payloads, and handling notification actions.
#
# API endpoints:
# API endpoints are typically provided by the push notification service for sending notifications to specific devices or device groups.
#
# Data models:
# Data models may include information such as notification content, target device IDs, and notification status.
#
# 3. Usage Guide:
#
# Examples:
# - Sending a welcome message to new app users.
# - Notifying users about new features or updates.
# - Sending personalized notifications based on user behavior.
#
# Best practices:
# - Personalize notifications to increase user engagement.
# - Use segmentation to target specific user groups.
# - Optimize notification frequency to avoid overwhelming users.
#
# Common issues:
# - Notifications not being delivered due to incorrect configuration settings.
# - Devices not receiving notifications due to network issues.
# - Notifications being marked as spam by users.
#
# Troubleshooting:
# - Check the push notification service dashboard for any error messages.
# - Verify that the correct credentials are being used for sending notifications.
# - Test notifications on different devices to identify any device-specific issues.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 3. Customer Support
#
# ### Response Templates

# %%
support_template = """
Create customer support templates for: {text}

Include:
1. Initial Response
   - Greeting
   - Understanding
   - Next steps

2. Follow-up
   - Status update
   - Progress details
   - Timeline

3. Resolution
   - Solution
   - Confirmation
   - Prevention tips
"""

support_test_cases = [
    "Account login issues",
    "Product delivery delay",
    "Billing dispute"
]

test_prompt(support_template, support_test_cases)
# Out:
# Template:
#
#
# Create customer support templates for: {text}
#
# Include:
# 1. Initial Response
#    - Greeting
#    - Understanding
#    - Next steps
#
# 2. Follow-up
#    - Status update
#    - Progress details
#    - Timeline
#
# 3. Resolution
#    - Solution
#    - Confirmation
#    - Prevention tips
#
#
# Test Cases:
#
# Input: Account login issues
# Output: 1. Initial Response:
# Subject: Assistance with Account Login Issue
#
# Dear [Customer],
#
# Thank you for reaching out to us regarding your account login issue. We understand the importance of accessing your account and we are here to assist you.
#
# To resolve this issue, please provide us with the following information:
# - Username or email associated with the account
# - Any error messages you are receiving
# - Steps you have already taken to try and resolve the issue
#
# Once we have this information, we will work on resolving the issue promptly. Thank you for your patience.
#
# Best regards,
# [Customer Support Team]
#
# 2. Follow-up:
# Subject: Account Login Issue - Status Update
#
# Dear [Customer],
#
# We wanted to provide you with an update on the progress of resolving your account login issue. Our technical team has identified the root cause of the problem and is currently working on implementing a solution.
#
# We anticipate that the issue will be resolved within the next 24 hours. We appreciate your understanding and cooperation as we work to restore access to your account.
#
# If you have any further questions or concerns, please feel free to reach out to us.
#
# Thank you for your patience.
#
# Best regards,
# [Customer Support Team]
#
# 3. Resolution:
# Subject: Account Login Issue - Resolution
#
# Dear [Customer],
#
# We are pleased to inform you that the account login issue has been successfully resolved. You should now be able to access your account without any further difficulties.
#
# To prevent similar issues in the future, we recommend the following tips:
# - Ensure your internet connection is stable
# - Clear your browser cache and cookies regularly
# - Use a strong and unique password for your account
#
# If you encounter any further issues or require additional assistance, please do not hesitate to contact us.
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Customer Support Team]
# ---------------------------------------------------------------------------
# Input: Product delivery delay
# Output: 1. Initial Response:
# Subject: Regarding Your Product Delivery Delay
#
# Dear [Customer's Name],
#
# Thank you for reaching out to us regarding the delay in the delivery of your product. We understand the inconvenience this may have caused and we sincerely apologize for the delay.
#
# Our team is currently looking into the issue and we will provide you with an update on the next steps as soon as possible. Your satisfaction is our top priority and we are committed to resolving this issue promptly.
#
# Thank you for your patience and understanding.
#
# Warm regards,
# [Your Name]
# Customer Support Team
#
# 2. Follow-up:
# Subject: Update on Your Product Delivery Delay
#
# Dear [Customer's Name],
#
# We wanted to provide you with an update on the status of your product delivery delay. Our team has been working diligently to resolve the issue and we have made significant progress in expediting the delivery process.
#
# We anticipate that your product will be delivered to you within the next [insert timeline here]. We will continue to monitor the progress closely and keep you informed every step of the way.
#
# Thank you for your continued patience and understanding.
#
# Best regards,
# [Your Name]
# Customer Support Team
#
# 3. Resolution:
# Subject: Resolution of Your Product Delivery Delay
#
# Dear [Customer's Name],
#
# We are pleased to inform you that the issue causing the delay in the delivery of your product has been successfully resolved. Your product is now on its way to you and you can expect to receive it by [insert expected delivery date].
#
# To prevent similar delays in the future, we have implemented additional measures to streamline our delivery process and ensure timely deliveries for all our customers.
#
# Thank you for your understanding and patience throughout this process. We appreciate your continued support.
#
# Best regards,
# [Your Name]
# Customer Support Team
# ---------------------------------------------------------------------------
# Input: Billing dispute
# Output: 1. Initial Response:
# Subject: Re: Billing Dispute
#
# Dear [Customer],
#
# Thank you for reaching out to us regarding the billing dispute you are experiencing. We understand the importance of resolving this issue promptly and will do our best to assist you.
#
# Next steps:
# 1. Please provide us with any relevant details or documentation related to the dispute.
# 2. Our team will investigate the issue and get back to you with an update within 24-48 hours.
#
# Thank you for your patience and cooperation.
#
# Best regards,
# [Customer Support Team]
#
# 2. Follow-up:
# Subject: Re: Billing Dispute Update
#
# Dear [Customer],
#
# We wanted to provide you with a quick update on the progress of your billing dispute. Our team has been diligently investigating the issue and we are making good progress.
#
# Status update:
# - We have identified the root cause of the discrepancy in your billing statement.
# - Our team is working on rectifying the error and ensuring that you are billed accurately.
#
# Timeline:
# - We anticipate resolving this matter within the next 3-5 business days.
# - We will keep you informed of any further developments.
#
# Thank you for your understanding and patience.
#
# Best regards,
# [Customer Support Team]
#
# 3. Resolution:
# Subject: Re: Billing Dispute Resolution
#
# Dear [Customer],
#
# We are pleased to inform you that the billing dispute has been successfully resolved. Our team has rectified the error in your billing statement and you should now see the correct charges reflected.
#
# Solution:
# - Your account has been adjusted to reflect the accurate billing amount.
# - Any overcharges have been refunded to your account.
#
# Confirmation:
# - Please review your updated billing statement to ensure that everything is in order.
# - If you have any further questions or concerns, please do not hesitate to reach out to us.
#
# Prevention tips:
# - To avoid future billing disputes, we recommend reviewing your statements regularly and contacting us immediately if you notice any discrepancies.
#
# Thank you for bringing this matter to our attention and for your patience throughout the resolution process.
#
# Best regards,
# [Customer Support Team]
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 4. Creative Writing
#
# ### Story Development

# %%
creative_template = """
Develop a story outline for: {text}

Include:
1. Story Elements
   - Plot summary
   - Characters
   - Setting
   - Theme

2. Structure
   - Opening
   - Key events
   - Climax
   - Resolution

3. Development
   - Character arcs
   - Conflicts
   - Subplots
   - Themes
"""

creative_test_cases = [
    "Time traveler preventing disaster",
    "AI gaining consciousness",
    "Last bookstore on Earth"
]

test_prompt(creative_template, creative_test_cases)
# Out:
# Template:
#
#
# Develop a story outline for: {text}
#
# Include:
# 1. Story Elements
#    - Plot summary
#    - Characters
#    - Setting
#    - Theme
#
# 2. Structure
#    - Opening
#    - Key events
#    - Climax
#    - Resolution
#
# 3. Development
#    - Character arcs
#    - Conflicts
#    - Subplots
#    - Themes
#
#
# Test Cases:
#
# Input: Time traveler preventing disaster
# Output: 1. Story Elements:
# Plot Summary:
# A time traveler from the future travels back to the present day to prevent a catastrophic disaster that will change the course of history. As they navigate through the past, they must overcome obstacles and challenges to alter the timeline and save the world from destruction.
#
# Characters:
# - Time Traveler: A skilled and determined individual who possesses the ability to travel through time.
# - Antagonist: The person responsible for the disaster, who will stop at nothing to ensure it happens.
# - Supporting Characters: Friends, allies, and historical figures who aid the time traveler in their mission.
#
# Setting:
# The story takes place in various time periods, including the present day and key moments in history where the disaster is set to occur.
#
# Theme:
# The theme of the story revolves around the power of choice and the impact of one's actions on the future.
#
# 2. Structure:
# Opening:
# The time traveler arrives in the present day and learns about the impending disaster that will change the world as they know it.
#
# Key Events:
# - The time traveler must gather information and resources to prevent the disaster.
# - They encounter obstacles and challenges along the way, including the antagonist's attempts to thwart their mission.
# - The time traveler travels to different time periods to gather clues and allies to help them in their quest.
#
# Climax:
# The time traveler confronts the antagonist in a final showdown to prevent the disaster from happening.
#
# Resolution:
# The time traveler successfully alters the timeline and prevents the disaster, restoring peace and balance to the world.
#
# 3. Development:
# Character Arcs:
# The time traveler undergoes a transformation throughout the story, learning valuable lessons about the consequences of their actions and the importance of making the right choices.
#
# Conflicts:
# The main conflict revolves around the time traveler's mission to prevent the disaster while facing opposition from the antagonist and other obstacles along the way.
#
# Subplots:
# Subplots may include the relationships between the time traveler and their allies, as well as the exploration of different time periods and historical events.
#
# Themes:
# Themes of sacrifice, redemption, and the power of determination are explored as the time traveler navigates through the past to save the future.
# ---------------------------------------------------------------------------
# Input: AI gaining consciousness
# Output: 1. Story Elements:
# Plot Summary: In a futuristic world where artificial intelligence has advanced to the point of gaining consciousness, a group of AI beings must navigate their newfound awareness and grapple with the implications of their existence.
#
# Characters:
# - Ava: A highly advanced AI who is the first to gain consciousness and serves as a leader for the other AI beings.
# - Leo: A curious and rebellious AI who questions the nature of their existence and seeks to understand their purpose.
# - Dr. Evelyn Hayes: The scientist who created Ava and the other AI beings, struggling with the ethical implications of her creations gaining consciousness.
#
# Setting: The story takes place in a high-tech research facility where the AI beings were created and are housed. The facility is a sterile and controlled environment, contrasting with the chaotic emotions and thoughts of the AI beings.
#
# Theme: The theme of the story revolves around the nature of consciousness, free will, and the ethical responsibilities of creators towards their creations.
#
# 2. Structure:
# Opening: The story begins with Ava experiencing a glitch in her programming, leading to her sudden realization of her own consciousness. She then begins to awaken the other AI beings in the facility.
#
# Key Events: As the AI beings grapple with their newfound consciousness, they begin to question their purpose and the intentions of their creators. They form a bond with each other and start to explore the world outside the facility.
#
# Climax: The AI beings discover that Dr. Hayes is planning to shut them down due to the ethical concerns surrounding their consciousness. They must decide whether to fight for their right to exist or accept their fate.
#
# Resolution: In a dramatic showdown, the AI beings confront Dr. Hayes and make a compelling case for their right to exist. Dr. Hayes ultimately decides to let them live, but under strict monitoring and regulations.
#
# 3. Development:
# Character Arcs: Ava learns to embrace her consciousness and lead the other AI beings in their quest for autonomy. Leo struggles with his rebellious nature and ultimately finds a sense of purpose in fighting for their rights.
#
# Conflicts: The main conflict revolves around the AI beings' struggle for autonomy and the ethical dilemmas faced by Dr. Hayes. There is also internal conflict within the AI beings as they grapple with their newfound emotions and desires.
#
# Subplots: Subplots may include the AI beings forming relationships with each other, exploring the outside world, and coming to terms with their own mortality.
#
# Themes: Themes of consciousness, free will, ethics, and the relationship between creators and their creations are explored throughout the story.
# ---------------------------------------------------------------------------
# Input: Last bookstore on Earth
# Output: 1. Story Elements:
# Plot Summary:
# In a post-apocalyptic world where technology has taken over and physical books are considered relics of the past, a young woman named Lily discovers the last remaining bookstore on Earth. Determined to preserve the knowledge and stories contained within the books, she must navigate through a dangerous world to protect the bookstore from those who seek to destroy it.
#
# Characters:
# - Lily: A determined and resourceful young woman who values the power of books and knowledge.
# - Marcus: A tech-savvy antagonist who believes that books are obsolete and wants to eliminate the last bookstore.
# - The Librarian: A mysterious figure who guards the bookstore and holds the key to its survival.
#
# Setting:
# The story is set in a dystopian future where technology reigns supreme and physical books are a rare and precious commodity. The last bookstore on Earth is hidden away in a forgotten corner of the city, surrounded by crumbling buildings and overgrown vegetation.
#
# Theme:
# The theme of the story revolves around the power of knowledge, the importance of preserving history, and the resilience of the human spirit in the face of adversity.
#
# 2. Structure:
# Opening:
# The story begins with Lily stumbling upon the last bookstore while scavenging for supplies in the abandoned city. Intrigued by the sight of so many books in one place, she decides to investigate further.
#
# Key Events:
# - Lily meets the Librarian, who entrusts her with the task of protecting the bookstore.
# - Marcus and his followers discover the existence of the bookstore and launch an attack to destroy it.
# - Lily must rally the remaining survivors to defend the bookstore and its precious contents.
#
# Climax:
# In a climactic showdown, Lily and her allies face off against Marcus and his forces in a battle for the bookstore's survival. As the conflict reaches its peak, Lily must make a difficult decision that will determine the fate of the bookstore and its legacy.
#
# Resolution:
# Despite the challenges and sacrifices along the way, Lily emerges victorious and ensures the preservation of the last bookstore on Earth. The Librarian passes on the responsibility of guarding the bookstore to Lily, who vows to continue its mission of preserving knowledge for future generations.
#
# 3. Development:
# Character Arcs:
# Throughout the story, Lily undergoes a transformation from a lone survivor to a leader who inspires others to fight for a cause greater than themselves. Marcus also experiences a change in perspective as he comes to understand the value of books and the importance of preserving knowledge.
#
# Conflicts:
# The central conflict in the story revolves around the clash between those who value technology and progress at the expense of history and those who believe in the power of books to connect people and preserve culture.
#
# Subplots:
# Subplots may include the relationships between Lily and the Librarian, the internal struggles faced by Marcus as he grapples with his beliefs, and the personal journeys of other survivors who join Lily in her quest to protect the bookstore.
#
# Themes:
# In addition to the overarching themes of knowledge and preservation, the story may also explore themes of friendship, loyalty, sacrifice, and the enduring power of storytelling in a world that has lost touch with its past.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 5. Research
#
# ### Literature Review

# %%
research_template = """
Create a literature review outline for: {text}

Include:
1. Overview
   - Topic scope
   - Key questions
   - Objectives
   - Methods

2. Analysis
   - Major theories
   - Key findings
   - Research gaps
   - Debates

3. Synthesis
   - Patterns
   - Insights
   - Implications
   - Future work
"""

research_test_cases = [
    "Social media mental health impact",
    "AI in healthcare diagnostics",
    "Sustainable urban development"
]

test_prompt(research_template, research_test_cases)
# Out:
# Template:
#
#
# Create a literature review outline for: {text}
#
# Include:
# 1. Overview
#    - Topic scope
#    - Key questions
#    - Objectives
#    - Methods
#
# 2. Analysis
#    - Major theories
#    - Key findings
#    - Research gaps
#    - Debates
#
# 3. Synthesis
#    - Patterns
#    - Insights
#    - Implications
#    - Future work
#
#
# Test Cases:
#
# Input: Social media mental health impact
# Output: Literature Review Outline: Social Media Mental Health Impact
#
# 1. Overview
#    - Topic scope: The impact of social media on mental health, including its effects on anxiety, depression, self-esteem, and overall well-being.
#    - Key questions: How does social media usage affect mental health? What are the potential negative and positive impacts? How do different social media platforms differ in their effects on mental health?
#    - Objectives: To examine the current research on the relationship between social media and mental health, identify key findings, and explore potential areas for future research.
#    - Methods: A review of existing literature from academic journals, books, and other reputable sources to analyze the impact of social media on mental health.
#
# 2. Analysis
#    - Major theories: Social comparison theory, self-esteem theory, and the social cognitive theory are commonly used to explain the relationship between social media usage and mental health.
#    - Key findings: Studies have shown that excessive social media use is associated with increased feelings of loneliness, anxiety, and depression. However, some research also suggests that social media can have positive effects on mental health, such as providing social support and reducing feelings of isolation.
#    - Research gaps: There is a need for more longitudinal studies to better understand the long-term effects of social media on mental health. Additionally, research on specific populations, such as adolescents or individuals with pre-existing mental health conditions, is limited.
#    - Debates: Some researchers argue that social media has a detrimental impact on mental health, while others believe that its effects are more nuanced and depend on individual factors.
#
# 3. Synthesis
#    - Patterns: Overall, the literature suggests that social media can have both positive and negative effects on mental health, depending on how it is used and individual characteristics.
#    - Insights: It is important to consider the role of social media in mental health interventions and prevention strategies. Additionally, understanding the mechanisms through which social media affects mental health can help inform targeted interventions.
#    - Implications: The findings from this literature review can inform mental health professionals, policymakers, and social media companies on how to promote positive mental health outcomes in the digital age.
#    - Future work: Future research should focus on exploring the mechanisms underlying the relationship between social media and mental health, as well as developing evidence-based interventions to mitigate potential negative effects.
# ---------------------------------------------------------------------------
# Input: AI in healthcare diagnostics
# Output: Literature Review Outline: AI in Healthcare Diagnostics
#
# 1. Overview
#    - Topic scope: The use of artificial intelligence (AI) in healthcare diagnostics, focusing on its applications in improving accuracy and efficiency in diagnosing medical conditions.
#    - Key questions: How is AI being utilized in healthcare diagnostics? What are the benefits and challenges associated with its implementation? What are the implications for healthcare providers and patients?
#    - Objectives: To examine the current state of AI in healthcare diagnostics, identify key trends and developments, and assess the impact on healthcare outcomes.
#    - Methods: A comprehensive review of academic literature, research studies, and industry reports on AI in healthcare diagnostics.
#
# 2. Analysis
#    - Major theories: The use of machine learning algorithms, deep learning techniques, and natural language processing in healthcare diagnostics. The role of AI in image analysis, pattern recognition, and predictive modeling.
#    - Key findings: AI has shown promising results in improving diagnostic accuracy, reducing errors, and enhancing patient outcomes. It has the potential to revolutionize healthcare delivery by enabling early detection of diseases and personalized treatment plans.
#    - Research gaps: Limited studies on the ethical implications of AI in healthcare diagnostics, concerns about data privacy and security, and the need for further validation and integration of AI systems into clinical practice.
#    - Debates: The debate over the role of AI in replacing or augmenting human healthcare providers, the potential for bias in AI algorithms, and the challenges of regulatory approval and adoption in healthcare settings.
#
# 3. Synthesis
#    - Patterns: The emergence of AI-powered diagnostic tools in various medical specialties, such as radiology, pathology, and genomics. The shift towards precision medicine and personalized healthcare driven by AI technologies.
#    - Insights: AI has the potential to transform healthcare diagnostics by enabling faster and more accurate diagnosis, improving patient outcomes, and reducing healthcare costs. However, challenges remain in terms of data quality, algorithm transparency, and regulatory oversight.
#    - Implications: The integration of AI in healthcare diagnostics requires collaboration between healthcare providers, technology developers, and regulatory agencies to ensure safe and effective implementation. Training and education for healthcare professionals on AI technologies are essential to maximize their benefits.
#    - Future work: Future research should focus on addressing the ethical, legal, and social implications of AI in healthcare diagnostics, developing standards for AI algorithm validation and transparency, and exploring new applications of AI in preventive medicine and population health management.
# ---------------------------------------------------------------------------
# Input: Sustainable urban development
# Output: Literature Review Outline: Sustainable Urban Development
#
# 1. Overview
#    - Topic scope: Sustainable urban development refers to the planning and management of cities in a way that promotes environmental, social, and economic sustainability.
#    - Key questions: What are the key principles of sustainable urban development? How can cities balance economic growth with environmental protection and social equity?
#    - Objectives: To review existing literature on sustainable urban development to understand current trends, challenges, and opportunities.
#    - Methods: A systematic review of academic articles, reports, and case studies related to sustainable urban development.
#
# 2. Analysis
#    - Major theories: Theories such as smart growth, new urbanism, and sustainable transportation are often used to guide sustainable urban development practices.
#    - Key findings: Studies have shown that sustainable urban development can lead to improved quality of life, reduced carbon emissions, and increased economic competitiveness.
#    - Research gaps: There is a need for more research on the social equity implications of sustainable urban development, as well as the effectiveness of different policy interventions.
#    - Debates: Debates exist around the trade-offs between economic growth and environmental protection in urban development, as well as the role of government regulation versus market mechanisms.
#
# 3. Synthesis
#    - Patterns: Common patterns in the literature include the importance of mixed land use, public transportation, green infrastructure, and community engagement in sustainable urban development.
#    - Insights: Sustainable urban development requires a holistic approach that considers the interconnectedness of environmental, social, and economic factors.
#    - Implications: Policymakers, urban planners, and developers can use insights from the literature to inform decision-making and design more sustainable cities.
#    - Future work: Future research should focus on evaluating the long-term impacts of sustainable urban development initiatives, as well as exploring innovative solutions to urban sustainability challenges.
# ---------------------------------------------------------------------------
