# %% [markdown]
# # Prompt Patterns - Part 2
#
# This notebook demonstrates additional prompt patterns, including success and failure cases.
#
# ## Patterns Covered
# 1. Error Identification
# 2. Prompt Improvement
# 3. Interaction Patterns
# 4. Context Control
#
# ## Setup

# %%
# !pip install openai langchain langchain-community
from openai import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# Initialize the OpenAI client
client = OpenAI(api_key="key")

# Initialize ChatOpenAI for LangChain
chat_model = ChatOpenAI(
    temperature=0,
    openai_api_key=client.api_key,
    model_name="gpt-3.5-turbo"
)
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.4)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Collecting langchain-community
#   Downloading langchain_community-0.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.19)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.143)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain
#   Downloading langchain-0.3.9-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain)
#   Downloading langchain_core-0.3.21-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.3.8-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 22.4 MB/s eta 0:00:00
# Downloading langchain-0.3.9-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.9 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain_core-0.3.21-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 12.3 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 33.4 MB/s eta 0:00:00
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: SQLAlchemy, python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-core, langchain, langchain-community
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# Successfully installed SQLAlchemy-2.0.35 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.9 langchain-community-0.3.8 langchain-core-0.3.21 marshmallow-3.23.1 mypy-extensions-1.0.0 pydantic-settings-2.6.1 python-dotenv-1.0.1 typing-inspect-0.9.0
# <ipython-input-1-309068b2fe03>:11: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   chat_model = ChatOpenAI(

# %% [markdown]
# ## Helper Functions

# %%
def get_completion(prompt, model="gpt-3.5-turbo", temperature=0):
    """Get completion from OpenAI API using the latest client"""
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature
    )
    return response.choices[0].message.content

def test_template(template, test_cases):
    """Test a template with multiple cases"""
    print("Template:\n")
    print(template)
    print("\nTest Cases:\n")
    for case in test_cases:
        print(f"Input: {case}")
        prompt = template.format(code=case)
        result = get_completion(prompt)
        print(f"Output: {result}")
        print("-"*75)

# %% [markdown]
# ## 1. Error Identification Pattern
#
# ### Success Cases

# %%
error_identification_template = """
Analyze the following code for potential errors and issues.
Provide a detailed report including:
1. Syntax errors
2. Logical errors
3. Best practice violations
4. Security concerns

For each issue found, provide:
- Issue type
- Description
- Severity (High/Medium/Low)
- Suggested fix

Code:
{code}
"""

success_cases = [
    """
    def calculate_average(numbers):
        total = 0
        for num in numbers:
            total += num
        return total/len(numbers)
    """,
    """
    password = "123456"
    user_input = input("Enter data: ")
    query = f"SELECT * FROM users WHERE id = {user_input}"
    """
]

print("Success Cases:")
test_template(error_identification_template, success_cases)
# Out:
# Success Cases:
# Template:
#
#
# Analyze the following code for potential errors and issues.
# Provide a detailed report including:
# 1. Syntax errors
# 2. Logical errors
# 3. Best practice violations
# 4. Security concerns
#
# For each issue found, provide:
# - Issue type
# - Description
# - Severity (High/Medium/Low)
# - Suggested fix
#
# Code:
# {code}
#
#
# Test Cases:
#
# Input:
#     def calculate_average(numbers):
#         total = 0
#         for num in numbers:
#             total += num
#         return total/len(numbers)
#
# Output: 1. Syntax errors:
#    - No syntax errors found in the provided code snippet.
#
# 2. Logical errors:
#    - None
#
# 3. Best practice violations:
#    - Function name should follow snake_case naming convention.
#    - Lack of input validation for the 'numbers' parameter.
#    - Division by zero error if 'numbers' is an empty list.
#
# 4. Security concerns:
#    - No security concerns identified in the provided code snippet.
#
# Suggestions:
# 1. Best practice violations:
#    - Rename the function to follow snake_case naming convention, for example: calculate_average.
#    - Add input validation to ensure 'numbers' is a list of numbers before performing calculations.
#    - Add a check to handle the case when 'numbers' is an empty list to avoid division by zero error. This can be done by returning 0 or raising an exception if the list is empty.
#
# Overall, the code is relatively clean and free of errors. It is recommended to address the best practice violations to improve the code quality and robustness.
# ---------------------------------------------------------------------------
# Input:
#     password = "123456"
#     user_input = input("Enter data: ")
#     query = f"SELECT * FROM users WHERE id = {user_input}"
#
# Output: 1. Syntax errors:
# - Issue: Missing database connection and execution of the query.
# - Severity: High
# - Suggested fix: Add database connection and execute the query using a database library like SQLAlchemy or psycopg2.
#
# 2. Logical errors:
# - Issue: Directly inserting user input into the query without sanitization or validation.
# - Severity: High
# - Suggested fix: Use parameterized queries or input validation to prevent SQL injection attacks.
#
# 3. Best practice violations:
# - Issue: Storing the password in plain text.
# - Severity: High
# - Suggested fix: Hash the password before storing it in the database using a secure hashing algorithm like bcrypt.
#
# 4. Security concerns:
# - Issue: Vulnerability to SQL injection attacks.
# - Severity: High
# - Suggested fix: Use parameterized queries or input validation to prevent SQL injection attacks.
#
# Overall, the code has critical issues related to SQL injection vulnerabilities and storing passwords in plain text. It is recommended to address these issues by implementing secure coding practices and using appropriate libraries for database interactions.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Failure Case

# %%
failure_cases = [
    "print Hello",  # Invalid syntax
    "x = 1"        # Too simple to analyze
]

print("Failure Cases:")
test_template(error_identification_template, failure_cases)
# Out:
# Failure Cases:
# Template:
#
#
# Analyze the following code for potential errors and issues.
# Provide a detailed report including:
# 1. Syntax errors
# 2. Logical errors
# 3. Best practice violations
# 4. Security concerns
#
# For each issue found, provide:
# - Issue type
# - Description
# - Severity (High/Medium/Low)
# - Suggested fix
#
# Code:
# {code}
#
#
# Test Cases:
#
# Input: print Hello
# Output: 1. Syntax errors:
# - Issue type: Syntax error
# - Description: The string "Hello" should be enclosed in quotes to be treated as a string literal.
# - Severity: Low
# - Suggested fix: Change the code to `print("Hello")`.
#
# 2. Logical errors:
# - N/A
#
# 3. Best practice violations:
# - Issue type: Best practice violation
# - Description: The print statement should have parentheses around the content to be printed.
# - Severity: Low
# - Suggested fix: Change the code to `print("Hello")`.
#
# 4. Security concerns:
# - N/A
# ---------------------------------------------------------------------------
# Input: x = 1
# Output: 1. Syntax errors:
#    - None
#
# 2. Logical errors:
#    - None
#
# 3. Best practice violations:
#    - Variable naming: The variable name "x" is not descriptive and does not convey the purpose of the variable.
#    - Lack of comments: There are no comments in the code to explain its purpose or functionality.
#
# 4. Security concerns:
#    - None
#
# Overall assessment:
# 1. Variable naming:
#    - Issue type: Best practice violation
#    - Description: The variable name "x" is not descriptive.
#    - Severity: Low
#    - Suggested fix: Use a more descriptive variable name that reflects the purpose of the variable, such as "counter" or "value".
#
# 2. Lack of comments:
#    - Issue type: Best practice violation
#    - Description: Lack of comments makes it difficult for other developers to understand the code.
#    - Severity: Low
#    - Suggested fix: Add comments to explain the purpose of the code and any important details.
#
# Overall, the code is simple and does not contain any syntax errors, logical errors, or security concerns. However, it can be improved by following best practices such as using descriptive variable names and adding comments for better readability and maintainability.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Fix: Comprehensive Error Analysis

# %%
robust_error_template = """
Perform a comprehensive code analysis following these guidelines:

Analysis Categories:
1. Syntax
   - Check for valid code structure
   - Identify missing elements
   - Validate syntax rules

2. Logic
   - Check for edge cases
   - Identify potential bugs
   - Validate business logic

3. Best Practices
   - Code style
   - Documentation
   - Maintainability

4. Security
   - Input validation
   - Data protection
   - Common vulnerabilities

For each issue found, provide:
- Category: Which analysis category
- Issue: Description of the problem
- Severity: High/Medium/Low
- Fix: How to resolve it

If code is too simple or invalid:
- Note the limitations
- Suggest improvements
- Provide example of proper code

Code to analyze:
{code}
"""

# Test with both success and failure cases
test_cases = success_cases + failure_cases
print("Testing Robust Template:")
test_template(robust_error_template, test_cases)
# Out:
# Testing Robust Template:
# Template:
#
#
# Perform a comprehensive code analysis following these guidelines:
#
# Analysis Categories:
# 1. Syntax
#    - Check for valid code structure
#    - Identify missing elements
#    - Validate syntax rules
#
# 2. Logic
#    - Check for edge cases
#    - Identify potential bugs
#    - Validate business logic
#
# 3. Best Practices
#    - Code style
#    - Documentation
#    - Maintainability
#
# 4. Security
#    - Input validation
#    - Data protection
#    - Common vulnerabilities
#
# For each issue found, provide:
# - Category: Which analysis category
# - Issue: Description of the problem
# - Severity: High/Medium/Low
# - Fix: How to resolve it
#
# If code is too simple or invalid:
# - Note the limitations
# - Suggest improvements
# - Provide example of proper code
#
# Code to analyze:
# {code}
#
#
# Test Cases:
#
# Input:
#     def calculate_average(numbers):
#         total = 0
#         for num in numbers:
#             total += num
#         return total/len(numbers)
#
# Output: Analysis:
#
# 1. Syntax:
#    - Issue: No input validation for the 'numbers' parameter.
#    - Severity: Medium
#    - Fix: Add input validation to check if 'numbers' is a list of numbers before performing calculations.
#
# 2. Logic:
#    - Issue: Division by zero error if 'numbers' is an empty list.
#    - Severity: High
#    - Fix: Add a check to handle the case when 'numbers' is empty before calculating the average.
#
# 3. Best Practices:
#    - Issue: Lack of documentation for the function.
#    - Severity: Low
#    - Fix: Add a docstring to describe the function's purpose, parameters, and return value.
#
# 4. Security:
#    - Issue: No data protection measures implemented.
#    - Severity: Low
#    - Fix: Implement data protection measures such as input validation and sanitization to prevent potential security vulnerabilities.
#
# Improvements:
# - Add input validation to ensure 'numbers' is a list of numbers.
# - Handle the case when 'numbers' is empty to avoid division by zero error.
# - Add documentation to describe the function's purpose and usage.
#
# Proper code example:
#
# ```python
# def calculate_average(numbers):
#     """
#     Calculate the average of a list of numbers.
#
#     Args:
#     numbers (list): A list of numbers.
#
#     Returns:
#     float: The average of the numbers in the list.
#     """
#     if not numbers or not all(isinstance(num, (int, float)) for num in numbers):
#         raise ValueError("Input must be a non-empty list of numbers")
#
#     total = sum(numbers)
#     return total / len(numbers)
# ```
# ---------------------------------------------------------------------------
# Input:
#     password = "123456"
#     user_input = input("Enter data: ")
#     query = f"SELECT * FROM users WHERE id = {user_input}"
#
# Output: Analysis:
#
# 1. Syntax:
#    - Issue: Lack of input validation for user_input variable.
#    - Severity: Medium
#    - Fix: Validate user_input to prevent SQL injection attacks. Use parameterized queries instead of string interpolation.
#
# 2. Logic:
#    - Issue: The password variable is hardcoded and not used in the code.
#    - Severity: Low
#    - Fix: Remove the unused password variable to improve code clarity.
#
# 3. Best Practices:
#    - Issue: Lack of comments or documentation to explain the purpose of the code.
#    - Severity: Low
#    - Fix: Add comments to explain the code functionality and purpose.
#
# 4. Security:
#    - Issue: Lack of input validation for user_input can lead to SQL injection attacks.
#    - Severity: High
#    - Fix: Use parameterized queries or input validation to prevent SQL injection attacks. Sanitize user input before using it in SQL queries.
#
# Improvements:
# - Implement input validation for user_input to prevent SQL injection attacks.
# - Remove unused variables to improve code readability.
# - Add comments to explain the code functionality.
#
# Proper code example:
#
# ```python
# import psycopg2
#
# # Get user input
# user_input = input("Enter user ID: ")
#
# # Connect to the database
# conn = psycopg2.connect("dbname=test user=postgres password=secret")
#
# # Create a cursor object
# cur = conn.cursor()
#
# # Execute a parameterized query
# cur.execute("SELECT * FROM users WHERE id = %s", (user_input,))
#
# # Fetch the results
# rows = cur.fetchall()
#
# # Close the cursor and connection
# cur.close()
# conn.close()
# ```
# ---------------------------------------------------------------------------
# Input: print Hello
# Output: Analysis:
#
# 1. Syntax
#    - Issue: Missing quotation marks around the string "Hello"
#    - Severity: Low
#    - Fix: Add quotation marks around the string to make it a valid string literal.
#    - Proper code: print("Hello")
#
# 2. Logic
#    - Issue: No logic errors found in the provided code.
#    - Severity: N/A
#    - Fix: N/A
#
# 3. Best Practices
#    - Issue: Lack of code style and proper formatting.
#    - Severity: Low
#    - Fix: Follow a consistent code style guide, such as PEP 8 for Python, and ensure proper indentation and formatting.
#    - Proper code: print("Hello")
#
# 4. Security
#    - Issue: No security vulnerabilities found in the provided code.
#    - Severity: N/A
#    - Fix: N/A
#
# Overall, the provided code is simple and lacks proper syntax and formatting. It is a basic print statement without any logic errors or security vulnerabilities. To improve the code, follow proper syntax rules, add quotation marks around the string, and maintain a consistent code style.
#
# Proper code:
# ```python
# print("Hello")
# ```
# ---------------------------------------------------------------------------
# Input: x = 1
# Output: Analysis Categories:
#
# 1. Syntax
# 2. Logic
# 3. Best Practices
# 4. Security
#
# Issues Found:
#
# 1. Syntax
#    - Issue: Missing code structure, no clear purpose or functionality.
#    - Severity: Low
#    - Fix: Add more code to provide context and functionality. For example, x = 1 + 2 to perform a simple addition operation.
#
# 2. Best Practices
#    - Issue: Lack of documentation and code style.
#    - Severity: Low
#    - Fix: Add comments to explain the purpose of the code and follow a consistent code style guide.
#
# Overall, the provided code is too simple and lacks context. It is recommended to expand the code with more functionality and adhere to best practices for documentation and code style.
#
# Example of proper code:
# ```
# # This code adds two numbers and stores the result in x
# x = 1 + 2
# print(x)
# ```
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 2. Prompt Improvement Pattern
#
# ### Success Cases

# %%
prompt_improvement_template = """
Analyze and improve the following prompt. Consider:
1. Clarity and specificity
2. Structure and organization
3. Constraints and requirements
4. Examples and context

Original prompt:
{code}

Provide:
1. Analysis of current prompt
2. Identified issues
3. Improved version
4. Explanation of changes
"""

success_cases = [
    "Write a blog post about AI",
    "Create a product description",
    "Explain quantum computing"
]

print("Success Cases:")
test_template(prompt_improvement_template, success_cases)
# Out:
# Success Cases:
# Template:
#
#
# Analyze and improve the following prompt. Consider:
# 1. Clarity and specificity
# 2. Structure and organization
# 3. Constraints and requirements
# 4. Examples and context
#
# Original prompt:
# {code}
#
# Provide:
# 1. Analysis of current prompt
# 2. Identified issues
# 3. Improved version
# 4. Explanation of changes
#
#
# Test Cases:
#
# Input: Write a blog post about AI
# Output: 1. Analysis of current prompt:
# The current prompt is quite vague and lacks specificity. It does not provide any guidance on what aspect of AI the blog post should focus on, leading to potential confusion for the writer.
#
# 2. Identified issues:
# - Lack of clarity and specificity: The prompt does not specify what aspect of AI the blog post should cover, leading to a broad and unfocused response.
# - Lack of structure and organization: Without a clear direction, the writer may struggle to organize their thoughts and create a cohesive blog post.
# - Lack of constraints and requirements: There are no guidelines or constraints provided, leaving the writer with too much freedom and potentially resulting in a lack of focus.
# - Lack of examples and context: Without any examples or context provided, the writer may not know where to start or what to include in the blog post.
#
# 3. Improved version:
# Write a blog post discussing the ethical implications of using AI in healthcare.
#
# Provide an analysis of how AI is currently being used in healthcare, the potential benefits and risks, and your perspective on the ethical considerations involved. Include real-world examples and case studies to support your arguments.
#
# 4. Explanation of changes:
# - The improved prompt provides clarity and specificity by focusing on a specific aspect of AI (healthcare) and highlighting the ethical implications.
# - By providing a clear structure and organization (analysis of current use, benefits and risks, ethical considerations), the writer is guided on how to approach the blog post.
# - Constraints and requirements are introduced by specifying the topic (ethical implications of AI in healthcare), helping the writer to stay focused and on track.
# - Examples and context are included in the prompt to give the writer a starting point and to help them understand what is expected in the blog post.
# ---------------------------------------------------------------------------
# Input: Create a product description
# Output: 1. The current prompt is vague and lacks specific details on what type of product is being described. It also does not provide any guidelines or requirements for the description.
#
# 2. The issues with the current prompt include lack of clarity, specificity, and structure. Without clear instructions or constraints, it is difficult for the writer to know what is expected in the product description.
#
# 3. Improved version:
# Write a product description for a new line of eco-friendly reusable water bottles.
#
# Provide details on the material, design, size, and features of the water bottles. Include information on how they are sustainable and environmentally friendly. The description should be concise, informative, and engaging to attract potential customers.
#
# 4. Explanation of changes:
# The improved version of the prompt specifies the type of product that needs to be described (eco-friendly reusable water bottles) and provides clear guidelines on what information should be included in the description. By adding details on the material, design, size, and features of the water bottles, as well as emphasizing their sustainability and environmental benefits, the writer has a better understanding of what is expected in the product description. This will result in a more focused and effective description that meets the needs of the target audience.
# ---------------------------------------------------------------------------
# Input: Explain quantum computing
# Output: 1. Analysis of current prompt:
# The current prompt is quite vague and lacks specificity. It does not provide any guidance on what aspects of quantum computing should be explained or what level of detail is expected. It also does not provide any context or examples to help the writer understand what is being asked.
#
# 2. Identified issues:
# - Lack of clarity and specificity: The prompt does not specify what exactly about quantum computing should be explained.
# - Lack of structure and organization: The prompt is a single sentence without any clear structure or organization.
# - Lack of constraints and requirements: The prompt does not provide any constraints or requirements for the explanation.
# - Lack of examples and context: The prompt does not provide any examples or context to help the writer understand what is being asked.
#
# 3. Improved version:
# Explain the principles of quantum computing, including how qubits differ from classical bits and how quantum superposition and entanglement are utilized in quantum algorithms. Provide examples of quantum algorithms such as Shor's algorithm or Grover's algorithm to illustrate the potential advantages of quantum computing over classical computing.
#
# 4. Explanation of changes:
# - Added specificity: The improved prompt specifies what aspects of quantum computing should be explained, such as qubits, quantum superposition, entanglement, and quantum algorithms.
# - Improved structure and organization: The improved prompt is divided into two main points - explaining the principles of quantum computing and providing examples of quantum algorithms.
# - Added constraints and requirements: The improved prompt includes a requirement to provide examples of quantum algorithms to demonstrate the advantages of quantum computing.
# - Added examples and context: The improved prompt specifically mentions examples of quantum algorithms to provide context and help the writer understand what is being asked.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Failure Case

# %%
failure_cases = [
    "Help",     # Too vague
    "Write"     # Incomplete prompt
]

print("Failure Cases:")
test_template(prompt_improvement_template, failure_cases)
# Out:
# Failure Cases:
# Template:
#
#
# Analyze and improve the following prompt. Consider:
# 1. Clarity and specificity
# 2. Structure and organization
# 3. Constraints and requirements
# 4. Examples and context
#
# Original prompt:
# {code}
#
# Provide:
# 1. Analysis of current prompt
# 2. Identified issues
# 3. Improved version
# 4. Explanation of changes
#
#
# Test Cases:
#
# Input: Help
# Output: 1. Analysis of current prompt:
# The current prompt is very vague and lacks specificity. It simply says "Help" without providing any context or direction for the reader. This can lead to confusion and make it difficult for someone to understand what kind of help is being requested.
#
# 2. Identified issues:
# - Lack of clarity and specificity
# - No structure or organization
# - No constraints or requirements
# - No examples or context provided
#
# 3. Improved version:
# "Please provide assistance with troubleshooting a technical issue on my computer. The issue involves my internet connection dropping frequently, and I have already tried restarting the router. Any suggestions or solutions would be greatly appreciated."
#
# 4. Explanation of changes:
# In the improved version, I added specific details about the help being requested, including the nature of the problem and the steps already taken to address it. This provides context for the reader and helps them understand the situation better. I also included a clear request for suggestions or solutions, giving the reader a clear direction on how they can help. This revised prompt is more structured, organized, and provides constraints and requirements for the assistance being sought.
# ---------------------------------------------------------------------------
# Input: Write
# Output: 1. Analysis of current prompt:
# The current prompt is very vague and lacks specificity. It simply says "Write" without providing any context or direction for the writing task. This can lead to confusion and uncertainty for the writer.
#
# 2. Identified issues:
# - Lack of clarity and specificity
# - No structure or organization
# - No constraints or requirements given
# - No examples or context provided
#
# 3. Improved version:
# Write a persuasive essay arguing for or against the use of technology in the classroom. Your essay should include at least three reasons to support your position and provide examples to illustrate your points.
#
# 4. Explanation of changes:
# In the improved version, I added specific instructions for the writing task by asking the writer to write a persuasive essay on a specific topic. I also provided clear requirements by asking for at least three reasons to support their position and examples to illustrate their points. This gives the writer a clear direction and structure for their writing, making the task more manageable and focused.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Fix: Structured Prompt Enhancement

# %%
robust_improvement_template = """
Analyze and enhance the prompt following this framework:

1. Prompt Analysis
   - Identify core intent
   - List missing elements
   - Evaluate clarity

2. Enhancement Areas
   - Specificity: Add clear requirements
   - Structure: Organize logically
   - Context: Provide relevant background
   - Examples: Include demonstrations

3. Output Format
   - Define expected format
   - Specify constraints
   - Set quality criteria

Original prompt:
{code}

Provide:
1. Original prompt analysis
   - Core purpose
   - Missing elements
   - Current strengths/weaknesses

2. Enhanced version
   - Clear structure
   - Added context
   - Example outputs

3. Improvement explanation
   - What changed
   - Why it helps
   - Expected impact
"""

# Test with both success and failure cases
test_cases = success_cases + failure_cases
print("Testing Robust Template:")
test_template(robust_improvement_template, test_cases)
# Out:
# Testing Robust Template:
# Template:
#
#
# Analyze and enhance the prompt following this framework:
#
# 1. Prompt Analysis
#    - Identify core intent
#    - List missing elements
#    - Evaluate clarity
#
# 2. Enhancement Areas
#    - Specificity: Add clear requirements
#    - Structure: Organize logically
#    - Context: Provide relevant background
#    - Examples: Include demonstrations
#
# 3. Output Format
#    - Define expected format
#    - Specify constraints
#    - Set quality criteria
#
# Original prompt:
# {code}
#
# Provide:
# 1. Original prompt analysis
#    - Core purpose
#    - Missing elements
#    - Current strengths/weaknesses
#
# 2. Enhanced version
#    - Clear structure
#    - Added context
#    - Example outputs
#
# 3. Improvement explanation
#    - What changed
#    - Why it helps
#    - Expected impact
#
#
# Test Cases:
#
# Input: Write a blog post about AI
# Output: 1. Prompt Analysis:
# - Core purpose: The core intent of the prompt is to write a blog post about AI.
# - Missing elements: The prompt lacks specificity in terms of what aspect of AI the blog post should focus on, the target audience, and the desired length or format of the post.
# - Clarity evaluation: The prompt is clear in terms of the general topic but lacks details that would guide the writer in creating a focused and engaging blog post.
#
# 2. Enhanced Version:
# Title: Crafting a Compelling Blog Post on the Impact of AI in Healthcare
#
# Structure:
# - Introduction: Brief overview of AI and its significance in healthcare.
# - Body:
#   1. Applications of AI in diagnosing diseases and treatment planning.
#   2. Ethical considerations and challenges in implementing AI in healthcare.
#   3. Future prospects and potential advancements in AI technology.
# - Conclusion: Recap of key points and a call to action for readers to explore further.
#
# Context:
# The blog post should target healthcare professionals, policymakers, and technology enthusiasts interested in the intersection of AI and healthcare. It should be around 800-1000 words in length and include relevant statistics and case studies to support the discussion.
#
# Example Outputs:
# - Introduction: "AI has revolutionized the healthcare industry, offering innovative solutions to complex challenges..."
# - Body: "One example of AI in healthcare is the use of machine learning algorithms to analyze medical imaging data..."
# - Conclusion: "As we navigate the evolving landscape of AI in healthcare, it is crucial to prioritize ethical considerations and ensure equitable access to these technologies."
#
# 3. Improvement Explanation:
# - What changed: The enhanced prompt provides a clear structure for the blog post, specifies the target audience and length, and includes relevant examples to guide the writer.
# - Why it helps: By providing more specific guidelines, the writer can create a more focused and engaging blog post that resonates with the intended audience.
# - Expected impact: The improved prompt is likely to result in a more informative and well-structured blog post that effectively communicates the impact of AI in healthcare to the target audience.
# ---------------------------------------------------------------------------
# Input: Create a product description
# Output: 1. Prompt Analysis:
#    - Core purpose: The core intent of the prompt is to have the participant create a product description.
#    - Missing elements: The prompt lacks specificity in terms of what type of product the description should be for, the target audience, and any specific requirements.
#    - Clarity evaluation: The prompt is clear in its basic request but lacks detail.
#
# 2. Enhancement Areas:
#    - Specificity: Specify the type of product (e.g., electronic gadget, clothing item, food product), target audience (e.g., children, young adults, seniors), and any unique features that should be highlighted.
#    - Structure: Provide a clear structure for the product description, such as including key features, benefits, and a call to action.
#    - Context: Offer background information on the product, its purpose, and why it stands out in the market.
#    - Examples: Include sample product descriptions to demonstrate the expected output.
#
# Enhanced Version:
# Describe a new line of eco-friendly kitchenware for environmentally conscious consumers. Highlight the sustainable materials used, the sleek design that complements modern kitchens, and the durability of the products. Include a call to action encouraging customers to make a positive impact on the environment with their purchase.
#
# 3. Improvement Explanation:
# - What changed: The enhanced version provides specific details about the type of product (eco-friendly kitchenware), the target audience (environmentally conscious consumers), and includes a structured format for the product description.
# - Why it helps: By adding specificity, structure, context, and examples, participants will have a clearer understanding of what is expected in their product description, leading to more focused and impactful responses.
# - Expected impact: The improved prompt will result in more detailed and engaging product descriptions that effectively showcase the unique selling points of the eco-friendly kitchenware, ultimately attracting potential customers and driving sales.
# ---------------------------------------------------------------------------
# Input: Explain quantum computing
# Output: 1. Prompt Analysis:
#    - Core purpose: The core intent of the prompt is to have the respondent explain quantum computing.
#    - Missing elements: The prompt lacks specificity in terms of what aspects of quantum computing should be explained and what level of detail is expected.
#    - Clarity evaluation: The prompt is clear in its request for an explanation of quantum computing but lacks depth in terms of guidance.
#
# 2. Enhanced Version:
#    - Clear structure: Explain the basic principles of quantum computing, its advantages over classical computing, and potential applications.
#    - Added context: Quantum computing utilizes quantum-mechanical phenomena to perform operations on data. It has the potential to revolutionize fields like cryptography, optimization, and simulation.
#    - Example outputs: Provide examples of quantum algorithms like Shor's algorithm for factoring large numbers and Grover's algorithm for searching unsorted databases.
#
# 3. Improvement Explanation:
#    - What changed: The enhanced version provides a clearer structure by breaking down the explanation into key components. It adds context to help the respondent understand the significance of quantum computing. Including examples demonstrates practical applications of quantum algorithms.
#    - Why it helps: The enhancements provide a more comprehensive understanding of quantum computing, guiding the respondent to cover essential aspects and showcase practical implications.
#    - Expected impact: By providing a clearer structure, context, and examples, the enhanced prompt is likely to elicit more detailed and insightful responses, leading to a better understanding of quantum computing for both the respondent and the audience.
# ---------------------------------------------------------------------------
# Input: Help
# Output: 1. Prompt Analysis:
#    - Core purpose: The core purpose of the prompt is to ask for assistance in analyzing and enhancing a given prompt.
#    - Missing elements: The original prompt lacks specificity in terms of what exactly needs to be analyzed and enhanced.
#    - Clarity: The prompt is clear in its request for help but lacks details on what exactly is being asked for.
#
# 2. Enhancement Areas:
#    - Specificity: Specify the prompt that needs to be analyzed and enhanced, such as a writing prompt, a coding prompt, etc.
#    - Structure: Clearly outline the steps for analyzing and enhancing the prompt in a logical manner.
#    - Context: Provide background information on why analyzing and enhancing prompts is important and how it can benefit the individual.
#    - Examples: Include sample prompts and demonstrate how they can be improved through analysis and enhancement.
#
# 3. Enhanced Version:
#    - Analyze and enhance the given writing prompt below:
#      "Describe a memorable experience you had and how it impacted you."
#
#    - Steps:
#      1. Identify the key elements of the prompt.
#      2. Evaluate the clarity and specificity of the prompt.
#      3. Enhance the prompt by adding specific details or instructions.
#
#    - Context: Analyzing and enhancing prompts can help individuals develop critical thinking skills and improve their ability to communicate effectively.
#
#    - Example Outputs:
#      Original prompt: "Describe a memorable experience you had and how it impacted you."
#      Enhanced prompt: "Reflect on a specific moment from your childhood that shaped your values and beliefs. Describe the event in detail and explain how it influenced your perspective on life."
#
# 3. Improvement Explanation:
#    - What changed: The enhanced version provides a specific writing prompt to analyze and enhance, outlines clear steps for the process, includes relevant context, and demonstrates an example of an improved prompt.
#    - Why it helps: This enhancement provides a clear and structured approach to analyzing and enhancing prompts, making it easier for individuals to understand and apply the concept.
#    - Expected impact: By following the outlined steps and examples, individuals can improve their skills in interpreting and refining prompts, leading to better writing and communication abilities.
# ---------------------------------------------------------------------------
# Input: Write
# Output: 1. Prompt Analysis:
# - Core purpose: The core purpose of the prompt is to analyze and enhance a given prompt following a specific framework.
# - Missing elements: The original prompt lacks specificity in terms of what prompt needs to be analyzed and enhanced, as well as the criteria for evaluation.
# - Clarity: The prompt is clear in terms of the overall objective but lacks specific details.
#
# 2. Enhancement Areas:
# - Specificity: Specify a sample prompt to be analyzed and enhanced, along with clear evaluation criteria.
# - Structure: Organize the prompt analysis and enhancement areas in a logical sequence.
# - Context: Provide background information on why analyzing and enhancing prompts is important in various contexts.
# - Examples: Include sample outputs of an analyzed and enhanced prompt.
#
# Enhanced Version:
# Analyze and enhance the given prompt "Write" using the provided framework.
# Provide:
# 1. Original prompt analysis:
#    - Core purpose: To evaluate and improve a given prompt.
#    - Missing elements: Lack of specificity and evaluation criteria.
#    - Current strengths/weaknesses: Clear objective but lacks details.
#
# 2. Enhanced version:
#    - Clear structure: Introduce the prompt, analyze its components, enhance with specific requirements, and evaluate based on set criteria.
#    - Added context: Explaining the importance of clear and specific prompts in communication.
#    - Example outputs: Demonstrate how the prompt "Write" can be enhanced with specific instructions and evaluation criteria.
#
# 3. Improvement explanation:
#    - What changed: Added specificity, structure, context, and examples to the prompt.
#    - Why it helps: Enhances understanding, provides a clear framework for analysis, and demonstrates practical application.
#    - Expected impact: Improved clarity, better analysis skills, and enhanced prompt creation abilities.
#
# 3. Output Format:
# - Define expected format: A well-structured analysis and enhancement of the given prompt.
# - Specify constraints: Ensure the analysis and enhancement stay within the framework provided.
# - Set quality criteria: Clear, logical, and practical improvements to the original prompt.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 3. Interaction Pattern
#
# ### Success Cases

# %%
interaction_template = """
Create an interactive troubleshooting guide for the following issue.
Include questions to ask the user and potential solutions based on their answers.

Issue:
{code}

Provide:
1. Initial assessment questions
2. Possible user responses
3. Next steps for each response
4. Solution recommendations
"""

success_cases = [
    "Computer won't start",
    "Website loading slowly",
    "Printer not responding"
]

print("Success Cases:")
test_template(interaction_template, success_cases)
# Out:
# Success Cases:
# Template:
#
#
# Create an interactive troubleshooting guide for the following issue.
# Include questions to ask the user and potential solutions based on their answers.
#
# Issue:
# {code}
#
# Provide:
# 1. Initial assessment questions
# 2. Possible user responses
# 3. Next steps for each response
# 4. Solution recommendations
#
#
# Test Cases:
#
# Input: Computer won't start
# Output: 1. Initial assessment questions:
# - Is the computer plugged in and receiving power?
# - Are there any error messages or beeping sounds when you try to start the computer?
# - Have you recently made any changes to the computer's hardware or software?
#
# 2. Possible user responses:
# - Yes, the computer is plugged in and receiving power.
# - No error messages or beeping sounds.
# - No recent changes to hardware or software.
#
# 3. Next steps for each response:
# - If the computer is plugged in and receiving power, try unplugging it and plugging it back in to ensure a secure connection. Check the power outlet and try a different one to rule out any issues with the power source.
# - If there are no error messages or beeping sounds, it could indicate a potential hardware issue. Try reseating the RAM and graphics card to ensure they are properly connected.
# - If there have been no recent changes to hardware or software, it may be a software-related issue. Try booting the computer in safe mode to see if it starts up successfully.
#
# 4. Solution recommendations:
# - If the computer still does not start after trying the above steps, it may be necessary to seek professional help to diagnose and repair the issue. It could be a faulty power supply, motherboard, or other hardware component that needs to be replaced.
# ---------------------------------------------------------------------------
# Input: Website loading slowly
# Output: 1. Initial assessment questions:
# - Is the slow loading issue happening on all devices or just one?
# - Is the slow loading issue happening on all pages of the website or just specific ones?
# - Have you recently made any changes to the website or added any new content?
# - Have you checked your internet connection speed?
#
# 2. Possible user responses:
# - Slow loading issue is happening on all devices.
# - Slow loading issue is happening on specific pages of the website.
# - Yes, I recently made changes to the website.
# - No, I have not checked my internet connection speed.
#
# 3. Next steps for each response:
# - If slow loading is happening on all devices, it could be a server-side issue. Check with your web hosting provider to see if there are any server problems.
# - If slow loading is happening on specific pages, there may be issues with the content on those pages. Check for large file sizes, excessive plugins, or any other elements that could be slowing down the page.
# - If changes were recently made to the website, try reverting back to a previous version to see if the slow loading issue persists. This can help identify if the changes are causing the problem.
# - If internet connection speed has not been checked, run a speed test to ensure that the issue is not related to a slow internet connection.
#
# 4. Solution recommendations:
# - Optimize images and videos on the website to reduce file sizes and improve loading times.
# - Minimize the use of plugins and scripts that may be slowing down the website.
# - Consider upgrading your web hosting plan to a faster server if the issue is server-related.
# - Implement a content delivery network (CDN) to help distribute website content and improve loading speeds for users in different locations.
# ---------------------------------------------------------------------------
# Input: Printer not responding
# Output: 1. Initial assessment questions:
# - Is the printer turned on?
# - Is the printer connected to the power source?
# - Is the printer connected to the computer?
# - Are there any error messages on the printer display or computer screen?
# - Have you recently installed any new software or updates on your computer?
#
# 2. Possible user responses:
# - Yes, the printer is turned on.
# - Yes, the printer is connected to the power source.
# - Yes, the printer is connected to the computer.
# - No error messages are displayed.
# - Yes, I recently installed new software or updates.
#
# 3. Next steps for each response:
# - If the printer is turned on, check the power source and make sure it is securely connected.
# - If the printer is connected to the power source, check the connection between the printer and the computer.
# - If there are no error messages, try restarting both the printer and the computer.
# - If new software or updates were installed, try uninstalling them and see if the printer responds.
#
# 4. Solution recommendations:
# - Check all connections and make sure they are secure.
# - Restart both the printer and the computer.
# - Check for any software conflicts or updates that may be causing the issue.
# - If the issue persists, consider contacting the printer manufacturer for further assistance.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Failure Case

# %%
failure_cases = [
    "It's broken",  # Too vague
    "Help me"       # Unclear issue
]

print("Failure Cases:")
test_template(interaction_template, failure_cases)
# Out:
# Failure Cases:
# Template:
#
#
# Create an interactive troubleshooting guide for the following issue.
# Include questions to ask the user and potential solutions based on their answers.
#
# Issue:
# {code}
#
# Provide:
# 1. Initial assessment questions
# 2. Possible user responses
# 3. Next steps for each response
# 4. Solution recommendations
#
#
# Test Cases:
#
# Input: It's broken
# Output: 1. Initial assessment questions:
# - Can you provide more details on what exactly is broken?
# - When did you first notice the issue?
# - Have you made any recent changes or updates to the device?
#
# 2. Possible user responses:
# - The screen is cracked and not displaying anything.
# - It stopped working yesterday.
# - I recently installed a new software update.
#
# 3. Next steps for each response:
# - If the screen is cracked and not displaying anything, the issue may be physical damage. In this case, the solution would be to replace the screen or take it to a professional for repair.
# - If it stopped working yesterday, try restarting the device to see if that resolves the issue. If not, check for any error messages or unusual behavior that could indicate a software problem.
# - If a new software update was recently installed, try rolling back the update to see if that resolves the issue. If not, consider contacting the manufacturer for further assistance.
#
# 4. Solution recommendations:
# - For physical damage such as a cracked screen, consider replacing the screen or taking it to a professional repair service.
# - For software issues, try restarting the device, rolling back recent updates, or contacting the manufacturer for support.
# ---------------------------------------------------------------------------
# Input: Help me
# Output: 1. Initial assessment questions:
# - What specific issue are you experiencing?
# - When did the issue start?
# - Have you made any recent changes to your device or software?
# - Are you receiving any error messages?
#
# 2. Possible user responses:
# - "My computer won't turn on."
# - "The issue started after I installed a new software update."
# - "I haven't made any changes recently."
# - "I am receiving an error message that says 'No bootable device found'."
#
# 3. Next steps for each response:
# - For "My computer won't turn on":
#    - Check if the power cable is properly connected.
#    - Try a different power outlet.
#    - Check if the power button is functioning properly.
#
# - For "The issue started after I installed a new software update":
#    - Try to uninstall the recent software update.
#    - Check for any compatibility issues with the update and your device.
#
# - For "I haven't made any changes recently":
#    - Check for any physical damage to the device.
#    - Try restarting the device.
#
# - For "I am receiving an error message that says 'No bootable device found'":
#    - Check if the hard drive is properly connected.
#    - Try accessing the BIOS settings to ensure the correct boot order.
#
# 4. Solution recommendations:
# - If the computer still does not turn on, it may be a hardware issue that requires professional assistance.
# - If the issue persists after uninstalling the software update, contact the software provider for further assistance.
# - If the error message continues to appear, it may indicate a problem with the hard drive that needs to be addressed by a technician.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Fix: Structured Interactive Guide

# %%
robust_interaction_template = """
Create a comprehensive troubleshooting guide following this structure:

1. Initial Assessment
   - Problem category
   - Severity level
   - Basic symptoms

2. Diagnostic Questions
   - Start with basic checks
   - Progress to specific issues
   - Include expected responses

3. Solution Paths
   - Quick fixes
   - Advanced solutions
   - Professional help criteria

4. Prevention Tips
   - Future prevention
   - Best practices
   - Regular maintenance

For vague or unclear issues:
1. Request clarification on:
   - Specific symptoms
   - When it started
   - Current impact

2. Provide examples of:
   - Clear problem descriptions
   - Relevant details to include
   - Proper terminology

Issue:
{code}
"""

# Test with both success and failure cases
test_cases = success_cases + failure_cases
print("Testing Robust Template:")
test_template(robust_interaction_template, test_cases)
# Out:
# Testing Robust Template:
# Template:
#
#
# Create a comprehensive troubleshooting guide following this structure:
#
# 1. Initial Assessment
#    - Problem category
#    - Severity level
#    - Basic symptoms
#
# 2. Diagnostic Questions
#    - Start with basic checks
#    - Progress to specific issues
#    - Include expected responses
#
# 3. Solution Paths
#    - Quick fixes
#    - Advanced solutions
#    - Professional help criteria
#
# 4. Prevention Tips
#    - Future prevention
#    - Best practices
#    - Regular maintenance
#
# For vague or unclear issues:
# 1. Request clarification on:
#    - Specific symptoms
#    - When it started
#    - Current impact
#
# 2. Provide examples of:
#    - Clear problem descriptions
#    - Relevant details to include
#    - Proper terminology
#
# Issue:
# {code}
#
#
# Test Cases:
#
# Input: Computer won't start
# Output: 1. Initial Assessment
#    - Problem category: Hardware failure
#    - Severity level: High
#    - Basic symptoms: Computer does not power on, no lights or sounds when pressing the power button
#
# 2. Diagnostic Questions
#    - Is the power cable securely connected to the computer and power outlet?
#    - Is the power outlet working by testing with another device?
#    - Have you recently made any hardware changes or updates?
#    - Have you experienced any power surges or outages recently?
#    - Do you hear any unusual noises coming from the computer when attempting to power it on?
#
# 3. Solution Paths
#    - Quick fixes: Check power connections, try a different power outlet, reset the power supply
#    - Advanced solutions: Test the power supply unit, check for loose connections inside the computer, test components individually
#    - Professional help criteria: If the power supply unit needs replacement, if there are hardware failures, if the issue persists after trying basic troubleshooting steps
#
# 4. Prevention Tips
#    - Use a surge protector to protect against power surges
#    - Regularly clean and maintain the computer to prevent hardware failures
#    - Avoid sudden power outages by using a UPS (Uninterruptible Power Supply)
#
# For vague or unclear issues:
# 1. Request clarification on:
#    - Specific symptoms: Is there any noise or light coming from the computer?
#    - When it started: Did the issue occur suddenly or after a specific event?
#    - Current impact: Is the inability to start the computer affecting any work or tasks?
#
# 2. Provide examples of:
#    - Clear problem descriptions: "Computer does not power on, no lights or sounds"
#    - Relevant details to include: Recent hardware changes, power surges, unusual noises
#    - Proper terminology: Power supply unit, hardware failure, surge protector
# ---------------------------------------------------------------------------
# Input: Website loading slowly
# Output: 1. Initial Assessment
#    - Problem category: Website performance
#    - Severity level: Moderate
#    - Basic symptoms: Pages taking a long time to load, slow response times, potential errors or timeouts
#
# 2. Diagnostic Questions
#    - Is the slow loading consistent across all pages or specific ones?
#    - Have you recently made any changes to the website or server configuration?
#    - Are other websites loading normally on the same network?
#    - Have you checked the website's server resources and performance metrics?
#    - Are there any error messages or warnings in the website's logs?
#
# 3. Solution Paths
#    - Quick fixes: Clear browser cache, optimize images and scripts, check server resources
#    - Advanced solutions: Enable caching, optimize server settings, consider content delivery network (CDN)
#    - Professional help criteria: If the issue persists after basic troubleshooting steps, consider consulting a web developer or hosting provider
#
# 4. Prevention Tips
#    - Regularly monitor website performance metrics
#    - Optimize images and scripts for faster loading times
#    - Implement caching mechanisms to improve website speed
#
# For vague or unclear issues:
# 1. Request clarification on:
#    - Specific symptoms: Are there any error messages or specific pages that are particularly slow?
#    - When it started: Did the slow loading issue start after a specific event or change?
#    - Current impact: How is the slow loading affecting user experience or website functionality?
#
# 2. Provide examples of:
#    - Clear problem descriptions: "Website takes 10+ seconds to load homepage"
#    - Relevant details to include: Server type, website platform, recent changes made
#    - Proper terminology: Caching, server resources, CDN
# ---------------------------------------------------------------------------
# Input: Printer not responding
# Output: 1. Initial Assessment
#    - Problem category: Hardware malfunction
#    - Severity level: Moderate
#    - Basic symptoms: Printer not printing, error messages on computer, printer offline status
#
# 2. Diagnostic Questions
#    - Is the printer turned on and connected to power?
#    - Is the printer connected to the computer via USB or wireless?
#    - Have you checked for any paper jams or low ink levels?
#    - Are there any error messages displayed on the printer or computer screen?
#    - Can you print a test page from the printer itself?
#
# 3. Solution Paths
#    - Quick fixes: Restart the printer and computer, check for paper jams, ensure printer is set as default, update printer drivers
#    - Advanced solutions: Reset printer settings, reinstall printer software, check network connection, run printer troubleshooter
#    - Professional help criteria: If the issue persists after trying basic and advanced solutions, contact the printer manufacturer or a technician for further assistance
#
# 4. Prevention Tips
#    - Future prevention: Regularly check for software updates, keep printer clean and well-maintained, use high-quality paper and ink cartridges
#    - Best practices: Follow manufacturer's guidelines for printer usage, avoid overloading the printer with print jobs
#    - Regular maintenance: Clean printer heads regularly, replace ink cartridges when low, keep printer in a dust-free environment
#
# For vague or unclear issues:
# 1. Request clarification on:
#    - Specific symptoms: What exactly happens when you try to print? Any error messages?
#    - When it started: Did the issue occur suddenly or after a specific event?
#    - Current impact: How is the non-responsive printer affecting your work or tasks?
#
# 2. Provide examples of:
#    - Clear problem descriptions: "Printer shows offline status and does not print any documents."
#    - Relevant details to include: Printer model, computer operating system, connection type (USB, wireless)
#    - Proper terminology: "Printer drivers" refer to software that allows the computer to communicate with the printer.
# ---------------------------------------------------------------------------
# Input: It's broken
# Output: 1. Initial Assessment
#    - Problem category: Hardware malfunction
#    - Severity level: High
#    - Basic symptoms: Device not turning on, unusual noises, error messages
#
# 2. Diagnostic Questions
#    - Is the device plugged in and receiving power?
#    - Have you tried restarting the device?
#    - Are there any error messages displayed on the screen?
#    - When did the issue start occurring?
#    - What were you doing when the issue started?
#
# 3. Solution Paths
#    - Quick fixes: Check power source, restart device
#    - Advanced solutions: Check hardware connections, run diagnostics
#    - Professional help criteria: If basic troubleshooting steps do not resolve the issue
#
# 4. Prevention Tips
#    - Regularly update software and drivers
#    - Avoid physical damage to the device
#    - Perform regular maintenance checks
#
# For vague or unclear issues:
# 1. Request clarification on:
#    - Specific symptoms: What exactly is happening when you try to use the device?
#    - When it started: Can you recall any specific event or action that may have caused the issue?
#    - Current impact: How is this issue affecting your work or daily routine?
#
# 2. Provide examples of:
#    - Clear problem descriptions: "The device does not power on when the power button is pressed."
#    - Relevant details to include: Model of the device, any recent software updates or changes
#    - Proper terminology: Use terms like "hardware malfunction" or "power source" to accurately describe the issue.
# ---------------------------------------------------------------------------
# Input: Help me
# Output: 1. Initial Assessment
#    - Problem category: General technical issue
#    - Severity level: Unknown
#    - Basic symptoms: Lack of specific information provided
#
# 2. Diagnostic Questions
#    - Have you encountered any error messages or warnings?
#    - Can you describe in detail what you are experiencing?
#    - When did this issue start occurring?
#
# 3. Solution Paths
#    - Quick fixes: Restart the device, check for software updates
#    - Advanced solutions: Run diagnostic tools, check hardware components
#    - Professional help criteria: If issue persists after basic troubleshooting steps
#
# 4. Prevention Tips
#    - Regularly update software and drivers
#    - Backup important data regularly
#    - Avoid downloading suspicious files or programs
#
# For vague or unclear issues:
# 1. Request clarification on:
#    - Specific symptoms: Provide detailed descriptions of what you are experiencing
#    - When it started: Include a timeline of when the issue first occurred
#    - Current impact: Explain how this issue is affecting your usage
#
# 2. Provide examples of:
#    - Clear problem descriptions: "I am unable to access the internet on my laptop."
#    - Relevant details to include: Operating system, device model, recent changes made
#    - Proper terminology: Use technical terms related to the issue for better understanding
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 4. Context Control Pattern
#
# ### Success Cases

# %%
context_control_template = """
Adapt the following text for different audiences while maintaining the core message.
Generate versions for:
1. Technical experts
2. General public
3. Young learners (age 10-14)

Text:
{code}

For each version, provide:
1. Adapted content
2. Key terms explained
3. Relevant examples
4. Engagement elements
"""

success_cases = [
    "Neural networks process data through interconnected nodes, similar to biological neurons.",
    "Climate change is causing global temperatures to rise due to greenhouse gas emissions.",
    "DNA contains genetic instructions that determine traits in living organisms."
]

print("Success Cases:")
test_template(context_control_template, success_cases)
# Out:
# Success Cases:
# Template:
#
#
# Adapt the following text for different audiences while maintaining the core message.
# Generate versions for:
# 1. Technical experts
# 2. General public
# 3. Young learners (age 10-14)
#
# Text:
# {code}
#
# For each version, provide:
# 1. Adapted content
# 2. Key terms explained
# 3. Relevant examples
# 4. Engagement elements
#
#
# Test Cases:
#
# Input: Neural networks process data through interconnected nodes, similar to biological neurons.
# Output: 1. Technical experts:
# Content: Neural networks utilize layers of interconnected nodes to process and analyze data, mimicking the structure of biological neurons in the brain.
# Key terms explained: Neural networks, interconnected nodes, biological neurons
# Examples: Convolutional neural networks used in image recognition, recurrent neural networks for natural language processing
# Engagement elements: Discussing advanced techniques like deep learning and backpropagation for training neural networks
#
# 2. General public:
# Content: Neural networks are like a computerized brain that processes information by connecting nodes together, similar to how our brains work with neurons.
# Key terms explained: Neural networks, interconnected nodes, neurons
# Examples: Facial recognition technology, recommendation systems on streaming platforms
# Engagement elements: Relating neural networks to everyday technologies like voice assistants and social media algorithms
#
# 3. Young learners (age 10-14):
# Content: Imagine a network of computer friends that work together to understand and learn things, just like how our brains have lots of tiny helpers called neurons.
# Key terms explained: Neural networks, interconnected nodes, neurons
# Examples: Sorting different types of animals, predicting the weather based on patterns
# Engagement elements: Using fun analogies like comparing neural networks to a team of robots solving puzzles together
# ---------------------------------------------------------------------------
# Input: Climate change is causing global temperatures to rise due to greenhouse gas emissions.
# Output: Technical experts:
#
# 1. Adapted content:
# The increase in global temperatures is primarily attributed to the enhanced greenhouse effect caused by the accumulation of greenhouse gases in the atmosphere.
#
# 2. Key terms explained:
# Greenhouse gases are gases that trap heat in the Earth's atmosphere, leading to a warming effect. The enhanced greenhouse effect refers to the additional warming caused by human activities, such as burning fossil fuels.
#
# 3. Relevant examples:
# Examples of greenhouse gases include carbon dioxide, methane, and nitrous oxide. The burning of fossil fuels for energy production and transportation is a major source of greenhouse gas emissions.
#
# 4. Engagement elements:
# Discussing the latest scientific research on climate change impacts and mitigation strategies, such as renewable energy technologies and carbon capture and storage.
#
# General public:
#
# 1. Adapted content:
# Climate change is making the Earth warmer because certain gases are trapping heat in the atmosphere.
#
# 2. Key terms explained:
# Greenhouse gases are like a blanket around the Earth, keeping it warm. When we burn fossil fuels like coal and gas, we release more of these gases into the air.
#
# 3. Relevant examples:
# Think of greenhouse gases as a cozy blanket that's getting thicker and making the Earth hotter. Driving cars and using electricity from power plants are some ways we add more of these gases to the air.
#
# 4. Engagement elements:
# Sharing relatable stories about how climate change is affecting communities around the world and simple actions individuals can take to reduce their carbon footprint.
#
# Young learners (age 10-14):
#
# 1. Adapted content:
# The Earth is getting warmer because of gases that act like a blanket, trapping heat in the air.
#
# 2. Key terms explained:
# Greenhouse gases are like invisible blankets that keep the Earth warm. When we use cars and factories, we make more of these gases that make the Earth even warmer.
#
# 3. Relevant examples:
# Imagine the Earth is like a big greenhouse, and the more gases we add, the hotter it gets. Planting trees and using less electricity can help keep the Earth cool.
#
# 4. Engagement elements:
# Creating interactive games or activities to demonstrate the concept of greenhouse gases and their impact on the environment. Encouraging young learners to think of ways they can help protect the Earth from getting too hot.
# ---------------------------------------------------------------------------
# Input: DNA contains genetic instructions that determine traits in living organisms.
# Output: Technical experts:
#
# 1. Adapted content:
# DNA, or deoxyribonucleic acid, is a molecule that carries genetic instructions for the development, functioning, growth, and reproduction of all known living organisms.
#
# 2. Key terms explained:
# DNA: Deoxyribonucleic acid, a molecule that contains the genetic instructions for life.
# Genetic instructions: Information encoded in DNA that determines an organism's traits.
#
# 3. Relevant examples:
# An example of DNA determining traits is how eye color is inherited from parents. The specific combination of genes in an individual's DNA will determine their eye color.
#
# 4. Engagement elements:
# Discussing the intricate process of DNA replication and how mutations can lead to genetic disorders can engage technical experts in the topic.
#
# General public:
#
# 1. Adapted content:
# DNA is like a blueprint that contains instructions for how living things grow, function, and look.
#
# 2. Key terms explained:
# DNA: The blueprint of life that determines traits in living organisms.
# Genetic instructions: Information in DNA that guides the development and characteristics of an organism.
#
# 3. Relevant examples:
# An example of DNA at work is how siblings can have similar physical features because they share genetic instructions from their parents.
#
# 4. Engagement elements:
# Using relatable examples like family traits can help the general public understand the concept of DNA and its role in determining traits.
#
# Young learners (age 10-14):
#
# 1. Adapted content:
# DNA is like a recipe book that tells our bodies how to grow, what color our eyes will be, and other cool stuff!
#
# 2. Key terms explained:
# DNA: The recipe book inside our cells that decides how we look and function.
# Genetic instructions: The information in DNA that tells our bodies how to develop and what traits we will have.
#
# 3. Relevant examples:
# Just like how a recipe tells you how to make a cake, DNA tells your body how to make you! It's why you might have your mom's curly hair or your dad's dimples.
#
# 4. Engagement elements:
# Using fun analogies like recipe books and comparing DNA to making a cake can make learning about genetics exciting for young learners.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Failure Case

# %%
failure_cases = [
    "x = y + z",  # Too abstract
    "It works"    # Lacks content
]

print("Failure Cases:")
test_template(context_control_template, failure_cases)
# Out:
# Failure Cases:
# Template:
#
#
# Adapt the following text for different audiences while maintaining the core message.
# Generate versions for:
# 1. Technical experts
# 2. General public
# 3. Young learners (age 10-14)
#
# Text:
# {code}
#
# For each version, provide:
# 1. Adapted content
# 2. Key terms explained
# 3. Relevant examples
# 4. Engagement elements
#
#
# Test Cases:
#
# Input: x = y + z
# Output: Technical experts:
#
# 1. Adapted content:
# The equation x = y + z represents the sum of two variables, y and z, being assigned to the variable x.
#
# 2. Key terms explained:
# - Equation: A mathematical statement that shows the relationship between two expressions.
# - Variables: Symbols that represent unknown or changing values in mathematical expressions.
#
# 3. Relevant examples:
# If y = 3 and z = 5, then x = 3 + 5 = 8.
#
# 4. Engagement elements:
# Discuss the implications of this equation in a specific technical context, such as in a computer programming algorithm.
#
# General public:
#
# 1. Adapted content:
# The equation x = y + z means that if you add the values of y and z together, you get the value of x.
#
# 2. Key terms explained:
# - Equation: A way to show a relationship between numbers or variables.
# - Variables: Letters used to represent unknown or changing values.
#
# 3. Relevant examples:
# If y = 10 and z = 7, then x = 10 + 7 = 17.
#
# 4. Engagement elements:
# Relate the concept to everyday situations where adding two values together is necessary, such as calculating expenses or measuring ingredients for a recipe.
#
# Young learners (age 10-14):
#
# 1. Adapted content:
# In this equation, x is equal to the sum of y and z. It's like putting together two puzzle pieces to find the missing piece.
#
# 2. Key terms explained:
# - Equation: A math sentence that shows two things are equal.
# - Variables: Letters that stand in for numbers we don't know yet.
#
# 3. Relevant examples:
# If y = 4 and z = 6, then x = 4 + 6 = 10.
#
# 4. Engagement elements:
# Use visual aids like colored blocks or drawings to illustrate the concept of combining values to find a solution. Ask questions to encourage critical thinking about different scenarios where this equation could be useful.
# ---------------------------------------------------------------------------
# Input: It works
# Output: Technical experts:
#
# 1. Adapted content:
# The system is functioning as intended.
#
# 2. Key terms explained:
# The system is operating within its specified parameters and delivering the expected results.
#
# 3. Relevant examples:
# The software update successfully resolved the bug, and the network is now running smoothly.
#
# 4. Engagement elements:
# Discuss the specific technical details of the system's functionality and how it impacts overall performance.
#
# General public:
#
# 1. Adapted content:
# Everything is running smoothly.
#
# 2. Key terms explained:
# The system is operating without any issues and is performing well.
#
# 3. Relevant examples:
# The website is loading quickly, and all features are working properly.
#
# 4. Engagement elements:
# Use relatable examples like everyday technology experiences to explain the concept in simple terms.
#
# Young learners (age 10-14):
#
# 1. Adapted content:
# It's all good!
#
# 2. Key terms explained:
# Everything is working as it should be.
#
# 3. Relevant examples:
# Your favorite video game is running without any glitches, and you can play it without any problems.
#
# 4. Engagement elements:
# Use fun and interactive examples like video games to help young learners understand the concept of things working properly.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Fix: Structured Context Adaptation

# %%
robust_context_template = """
Adapt content for multiple audiences following these guidelines:

1. Audience Profiles
   Technical Experts:
   - Advanced vocabulary
   - Technical details
   - Industry context

   General Public:
   - Clear language
   - Practical examples
   - Relevant analogies

   Young Learners:
   - Simple words
   - Visual descriptions
   - Interactive elements

2. Content Elements
   - Core message
   - Key concepts
   - Supporting details
   - Examples

3. Engagement Features
   - Questions
   - Activities
   - Real-world connections

For abstract or unclear content:
1. Identify core concept
2. Provide context
3. Add concrete examples
4. Suggest improvements

Text:
{code}

Provide for each audience:
1. Adapted content
2. Key terms and explanations
3. Examples and analogies
4. Engagement elements
5. Comprehension checks
"""

# Test with both success and failure cases
test_cases = success_cases + failure_cases
print("Testing Robust Template:")
test_template(robust_context_template, test_cases)
# Out:
# Testing Robust Template:
# Template:
#
#
# Adapt content for multiple audiences following these guidelines:
#
# 1. Audience Profiles
#    Technical Experts:
#    - Advanced vocabulary
#    - Technical details
#    - Industry context
#
#    General Public:
#    - Clear language
#    - Practical examples
#    - Relevant analogies
#
#    Young Learners:
#    - Simple words
#    - Visual descriptions
#    - Interactive elements
#
# 2. Content Elements
#    - Core message
#    - Key concepts
#    - Supporting details
#    - Examples
#
# 3. Engagement Features
#    - Questions
#    - Activities
#    - Real-world connections
#
# For abstract or unclear content:
# 1. Identify core concept
# 2. Provide context
# 3. Add concrete examples
# 4. Suggest improvements
#
# Text:
# {code}
#
# Provide for each audience:
# 1. Adapted content
# 2. Key terms and explanations
# 3. Examples and analogies
# 4. Engagement elements
# 5. Comprehension checks
#
#
# Test Cases:
#
# Input: Neural networks process data through interconnected nodes, similar to biological neurons.
# Output: Technical Experts:
# 1. Adapted content:
# Neural networks are a type of machine learning algorithm that processes data through interconnected nodes, mimicking the way biological neurons work in the human brain.
#
# 2. Key terms and explanations:
# - Neural networks: Machine learning algorithms that process data through interconnected nodes.
# - Nodes: Individual units within a neural network that receive input, perform a calculation, and pass the output to the next layer of nodes.
# - Neurons: Cells in the human brain that transmit information through electrical and chemical signals.
#
# 3. Examples and analogies:
# Imagine a neural network as a complex web of interconnected nodes, where each node is like a neuron in the brain. Just like how neurons in our brain communicate with each other to process information, nodes in a neural network work together to analyze and interpret data.
#
# 4. Engagement elements:
# - Questions: How do neural networks differ from traditional algorithms in processing data?
# - Activities: Create a simple neural network diagram and explain how data flows through it.
# - Real-world connections: How are neural networks used in image recognition or natural language processing?
#
# General Public:
# 1. Adapted content:
# Neural networks are like a computer system that processes information by connecting different parts together, similar to how our brain works with neurons.
#
# 2. Key terms and explanations:
# - Neural networks: Computer systems that process information by connecting different parts together.
# - Nodes: Parts of a neural network that work together to analyze data.
# - Neurons: Cells in the brain that help us think and process information.
#
# 3. Examples and analogies:
# Think of a neural network as a team of workers in an office, where each person has a specific role to play. Just like how they collaborate to get work done, nodes in a neural network work together to understand and interpret data.
#
# 4. Engagement elements:
# - Questions: How can neural networks be used in everyday technology like smartphones or social media?
# - Activities: Draw a simple neural network diagram and explain how it processes information.
# - Real-world connections: How does facial recognition technology use neural networks to identify people?
#
# Young Learners:
# 1. Adapted content:
# Neural networks are like a group of friends working together to solve a puzzle, where each friend has a special job to do.
#
# 2. Key terms and explanations:
# - Neural networks: A group of friends working together to solve a puzzle.
# - Nodes: Friends in the group who each have a special job to help solve the puzzle.
# - Neurons: Friends in the brain who help us think and learn new things.
#
# 3. Examples and analogies:
# Imagine you and your friends are trying to solve a big puzzle together. Each friend has a specific piece of the puzzle to work on, just like how nodes in a neural network have their own tasks to complete.
#
# 4. Engagement elements:
# - Questions: How do you think neural networks can help us learn new things like a group of friends?
# - Activities: Draw a picture of a neural network with each node represented by a different friend.
# - Real-world connections: How can neural networks be used in games or apps that you use on your tablet or computer?
# ---------------------------------------------------------------------------
# Input: Climate change is causing global temperatures to rise due to greenhouse gas emissions.
# Output: Technical Experts:
# 1. Adapted content:
# Climate change is a phenomenon where the Earth's average temperature increases due to the accumulation of greenhouse gases in the atmosphere, primarily from human activities such as burning fossil fuels and deforestation.
#
# 2. Key terms and explanations:
# - Climate change: The long-term alteration of temperature and typical weather patterns in a place.
# - Greenhouse gases: Gases like carbon dioxide and methane that trap heat in the Earth's atmosphere, leading to global warming.
#
# 3. Examples and analogies:
# - Analogy: Think of the Earth's atmosphere like a blanket. When greenhouse gases increase, it's like adding more layers to the blanket, causing the Earth to get warmer.
# - Example: The burning of fossil fuels releases carbon dioxide into the atmosphere, contributing to the greenhouse effect and global warming.
#
# 4. Engagement elements:
# - Questions: How do greenhouse gases contribute to global warming?
# - Activities: Calculate your carbon footprint and explore ways to reduce it.
# - Real-world connections: Discuss current climate change policies and their effectiveness in reducing greenhouse gas emissions.
#
# 5. Comprehension checks:
# - What are greenhouse gases, and how do they affect the Earth's temperature?
# - How can individuals and industries reduce their carbon footprint to mitigate climate change?
#
# General Public:
# 1. Adapted content:
# Climate change is when the Earth's temperature goes up because gases like carbon dioxide trap heat in the air. This happens when people burn fossil fuels and cut down trees.
#
# 2. Key terms and explanations:
# - Climate change: When the Earth gets warmer because of gases in the air.
# - Greenhouse gases: Gases that trap heat in the Earth's atmosphere, causing global warming.
#
# 3. Examples and analogies:
# - Analogy: Imagine the Earth like a car with the windows rolled up on a hot day. Greenhouse gases act like the windows, trapping heat inside.
# - Example: When we drive cars or use electricity from coal plants, we release greenhouse gases that warm the planet.
#
# 4. Engagement elements:
# - Questions: How can we reduce our impact on climate change in our daily lives?
# - Activities: Plant a tree or start a compost bin to help reduce greenhouse gas emissions.
# - Real-world connections: Learn about how climate change is affecting wildlife and natural habitats.
#
# 5. Comprehension checks:
# - What causes climate change, and how does it affect the Earth?
# - What are some ways we can help reduce greenhouse gas emissions in our communities?
#
# Young Learners:
# 1. Adapted content:
# Climate change means the Earth is getting hotter because of gases that trap heat in the air. People make the Earth warmer by burning things like gas and cutting down trees.
#
# 2. Key terms and explanations:
# - Climate change: When the Earth gets hotter because of gases in the air.
# - Greenhouse gases: Gases that act like a blanket around the Earth, keeping it warm.
#
# 3. Examples and analogies:
# - Analogy: Picture the Earth like a big greenhouse, with gases wrapping around it like a cozy blanket.
# - Example: When we use cars or factories, we make more greenhouse gases that warm up the Earth.
#
# 4. Engagement elements:
# - Questions: How can we help keep the Earth cool?
# - Activities: Draw a picture of ways to reduce greenhouse gases in your neighborhood.
# - Real-world connections: Visit a local park and learn about how trees help absorb carbon dioxide.
#
# 5. Comprehension checks:
# - Why is the Earth getting warmer, and what can we do to help?
# - How do trees and plants help reduce greenhouse gases in the atmosphere?
# ---------------------------------------------------------------------------
# Input: DNA contains genetic instructions that determine traits in living organisms.
# Output: Technical Experts:
# 1. Adapted content: DNA, or deoxyribonucleic acid, is a molecule that carries genetic information in living organisms, determining their traits through the instructions it contains.
# 2. Key terms and explanations: DNA, genetic instructions, traits, living organisms
# 3. Examples and analogies: Think of DNA as a blueprint that guides the construction of a building, determining its design and features.
# 4. Engagement elements: Discuss the latest advancements in DNA sequencing technologies and their impact on genetic research.
# 5. Comprehension checks: How does DNA play a role in the development of genetically modified organisms?
#
# General Public:
# 1. Adapted content: DNA is like a set of instructions that tells living things how to look and function.
# 2. Key terms and explanations: DNA, genetic instructions, traits, living organisms
# 3. Examples and analogies: Just like a recipe tells you how to make a cake, DNA tells your body how to make you!
# 4. Engagement elements: Explore how DNA testing kits can reveal your ancestry and health risks based on your genetic makeup.
# 5. Comprehension checks: How does DNA influence the color of your eyes or the shape of your nose?
#
# Young Learners:
# 1. Adapted content: DNA is like a special code that tells plants, animals, and people how to grow and be unique.
# 2. Key terms and explanations: DNA, genetic instructions, traits, living organisms
# 3. Examples and analogies: Imagine DNA as a magical recipe book that creates different creatures with different features.
# 4. Engagement elements: Create a DNA model using colorful beads to represent the different building blocks of DNA.
# 5. Comprehension checks: Can you draw a picture showing how DNA helps a baby grow into a child?
# ---------------------------------------------------------------------------
# Input: x = y + z
# Output: Technical Experts:
# 1. Adapted content: The equation x = y + z represents the relationship between three variables.
# 2. Key terms and explanations: In this equation, x is equal to the sum of y and z.
# 3. Examples and analogies: For example, if y = 2 and z = 3, then x would be 5.
# 4. Engagement elements: Discuss how this equation is used in specific technical applications or industries.
# 5. Comprehension checks: Ask technical experts to explain how they would apply this equation in a real-world scenario.
#
# General Public:
# 1. Adapted content: The equation x = y + z shows how three things are related to each other.
# 2. Key terms and explanations: In this equation, x is the result of adding y and z together.
# 3. Examples and analogies: Think of x as a cake, y as flour, and z as sugar. When you mix flour and sugar together, you get a cake (x).
# 4. Engagement elements: Provide a simple math problem using this equation for the audience to solve.
# 5. Comprehension checks: Ask the audience to explain in their own words what the equation x = y + z means.
#
# Young Learners:
# 1. Adapted content: The equation x = y + z is like putting two things together to get a new thing.
# 2. Key terms and explanations: In this equation, x is what you get when you add y and z.
# 3. Examples and analogies: Imagine y as apples and z as oranges. When you put them together, you get a fruit salad (x).
# 4. Engagement elements: Create a visual representation of the equation using pictures of different objects to represent x, y, and z.
# 5. Comprehension checks: Ask young learners to draw their own version of the equation using their favorite objects.
# ---------------------------------------------------------------------------
# Input: It works
# Output: Technical Experts:
# 1. Adapted content: The functionality operates efficiently within the specified parameters.
# 2. Key terms and explanations: Functionality, efficiency, parameters
# 3. Examples and analogies: Think of it as a well-oiled machine that performs optimally within its designated limits.
# 4. Engagement elements: Discuss the impact of exceeding parameters on performance.
# 5. Comprehension checks: How does the efficiency of the functionality affect overall performance?
#
# General Public:
# 1. Adapted content: It does what it's supposed to do effectively.
# 2. Key terms and explanations: Works, effectively
# 3. Examples and analogies: Imagine a car running smoothly on the road without any issues.
# 4. Engagement elements: Ask how important it is for things to work as intended in daily life.
# 5. Comprehension checks: Why is it important for things to work properly?
#
# Young Learners:
# 1. Adapted content: It does its job well.
# 2. Key terms and explanations: Job, well
# 3. Examples and analogies: Like a robot completing a task perfectly every time.
# 4. Engagement elements: Draw a picture of something working correctly and ask them to describe it.
# 5. Comprehension checks: Can you explain what it means for something to work well?
# ---------------------------------------------------------------------------
